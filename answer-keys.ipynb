# %% [markdown]
# # Import Data

# %%
# We only need two packages here
library(data.table)
library(stringr)

# set `data_path` to your dir
data_path <- "C:/Users/rossz/OneDrive/App/R/stock-datatable-key/data"
setwd(data_path)

# read into data
data <- readRDS("stock-market-data.rds")
data[1:5] # show top 5 obs
# Out:
#   symbol    date     pre_close open high low  close volume    amount
# 1 600000.SH 20120104 8.49      8.54 8.56 8.39 8.41   34201379  290229551
# 2 600000.SH 20120105 8.41      8.47 8.82 8.47 8.65  132116203 1144753023
# 3 600000.SH 20120106 8.65      8.63 8.78 8.62 8.71   61778687  537043761
# 4 600000.SH 20120109 8.71      8.72 8.99 8.68 8.95   80136249  711429611
# 5 600000.SH 20120110 8.95      8.95 9.10 8.88 9.07   72004632  647206633
#   adj_factor capt         index_w50  index_w300 index_w500 industry
# 1 6.655275   125500555680 0.04640928 0.02125936 0          BANKS
# 2 6.655275   129082022192 0.04640928 0.02125936 0          BANKS
# 3 6.655275   129977388820 0.04640928 0.02125936 0          BANKS
# 4 6.655275   133558855331 0.04640928 0.02125936 0          BANKS
# 5 6.655275   135349588587 0.04640928 0.02125936 0          BANKS

# %% [markdown]
# # Answer Keys

# %% [markdown]
# ## 1. 哪些股票的代码中包含"8"这个数字？

# %%
data[str_detect(symbol, "8"), unique(symbol)]
# Out:
#   [1] "600008.SH" "600018.SH" "600028.SH" "600038.SH" "600048.SH" "600058.SH"
#   [7] "600068.SH" "600078.SH" "600080.SH" "600081.SH" "600082.SH" "600083.SH"
#  [13] "600084.SH" "600085.SH" "600086.SH" "600087.SH" "600088.SH" "600089.SH"
#  [19] "600098.SH" "600108.SH" "600118.SH" "600128.SH" "600138.SH" "600148.SH"
#  [25] "600158.SH" "600168.SH" "600178.SH" "600180.SH" "600182.SH" "600183.SH"
#  [31] "600184.SH" "600185.SH" "600186.SH" "600187.SH" "600188.SH" "600189.SH"
#  [37] "600198.SH" "600208.SH" "600218.SH" "600228.SH" "600238.SH" "600248.SH"
#  [43] "600258.SH" "600268.SH" "600278.SH" "600280.SH" "600281.SH" "600282.SH"
#  [49] "600283.SH" "600284.SH" "600285.SH" "600287.SH" "600288.SH" "600289.SH"
#  [55] "600298.SH" "600308.SH" "600318.SH" "600328.SH" "600338.SH" "600348.SH"
#  [61] "600358.SH" "600368.SH" "600378.SH" "600380.SH" "600381.SH" "600382.SH"
#  [67] "600383.SH" "600385.SH" "600386.SH" "600387.SH" "600388.SH" "600389.SH"
#  [73] "600398.SH" "600408.SH" "600418.SH" "600428.SH" "600438.SH" "600448.SH"
#  [79] "600458.SH" "600468.SH" "600478.SH" "600480.SH" "600481.SH" "600482.SH"
#  [85] "600483.SH" "600485.SH" "600486.SH" "600487.SH" "600488.SH" "600489.SH"
#  [91] "600498.SH" "600508.SH" "600518.SH" "600528.SH" "600538.SH" "600548.SH"
#  [97] "600558.SH" "600568.SH" "600578.SH" "600580.SH" "600581.SH" "600582.SH"
# [103] "600583.SH" "600584.SH" "600585.SH" "600586.SH" "600587.SH" "600588.SH"
# 224 20120118 UP    45
# 225 20120302 DOWN  13
# 226 20120412 DOWN  20
# 227 20120418 DOWN  21
# 228 20120621 UP    32
# 229 20120109 DOWN   8
# 230 20120110 DOWN   5
# 231 20120202 DOWN  11
# 232 20120328 UP     7
# 233 20120207 UP    18
# 234 20120117 DOWN   5

# %% [markdown]
# #### *5. 每天每个行业各有多少只股票？*

# %%
data[, .(stk_num = uniqueN(symbol)), by = .(date, industry)]
# Out:
#      date     industry stk_num
# 1    20120104 BANKS    16
# 2    20120105 BANKS    16
# 3    20120106 BANKS    16
# 4    20120109 BANKS    16
# 5    20120110 BANKS    16
# 6    20120111 BANKS    16
# 7    20120112 BANKS    16
# 8    20120113 BANKS    16
# 9    20120116 BANKS    16
# 10   20120117 BANKS    16
# 11   20120118 BANKS    16
# 12   20120119 BANKS    16
# 13   20120120 BANKS    16
# 14   20120130 BANKS    16
# 15   20120131 BANKS    16
# 16   20120201 BANKS    16
# 17   20120202 BANKS    16
# 18   20120203 BANKS    16
# 19   20120206 BANKS    16
# 20   20120207 BANKS    16
# 21   20120208 BANKS    16
# 22   20120209 BANKS    16
# 23   20120210 BANKS    16
# 24   20120213 BANKS    16
# 25   20120214 BANKS    16
# 26   20120215 BANKS    16
# 27   20120216 BANKS    16
# 28   20120217 BANKS    16
# 29   20120220 BANKS    16
# 30   20120221 BANKS    16
# ...  ...      ...      ...
# 3715 20120615 COMSERV  29
# 3716 20120618 COMSERV  29
# 3717 20120619 COMSERV  29
# 3718 20120620 COMSERV  29
# 3719 20120621 COMSERV  29
# 3720 20120625 COMSERV  29
# 3721 20120626 COMSERV  29
# 3722 20120627 COMSERV  29
# 3723 20120628 COMSERV  29
# 3724 20120629 COMSERV  29
# 3725 20120601 INDCONG  11
# 3726 20120604 INDCONG  11
# 3727 20120605 INDCONG  11
# 3728 20120606 INDCONG  11
# 3729 20120607 INDCONG  11
# 3730 20120608 INDCONG  11
# 3731 20120611 INDCONG  11
# 3732 20120612 INDCONG  11
# 3733 20120613 INDCONG  11
# 3734 20120614 INDCONG  11
# 3735 20120615 INDCONG  11
# 3736 20120618 INDCONG  11
# 3737 20120619 INDCONG  11
# 3738 20120620 INDCONG  11
# 3739 20120621 INDCONG  11
# 3740 20120625 INDCONG  11
# 3741 20120626 INDCONG  11
# 3742 20120627 INDCONG  11
# 3743 20120628 INDCONG  11
# 3744 20120629 INDCONG  11

# %% [markdown]
# #### *6. 股票数最大的行业和总成交额最大的行业是否总是同一个行业？*

# %% [markdown]
# ##### 6.1 *Key 1*

# %%
data1 <- data[, .(trd_amount = sum(amount), stk_num = uniqueN(symbol)), by = .(date, industry)]
data1[data1[, .I[trd_amount == max(trd_amount)], by = date]$V1]$industry == data1[data1[, .I[stk_num == max(stk_num)], by = date]$V1]$industry
# Out:
#   [1]  TRUE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
#  [25] FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE
#  [37]  TRUE  TRUE  TRUE FALSE  TRUE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE
#  [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE
#  [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [97]  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE

# %% [markdown]
# ##### 6.2 *Key 2*

# %%
data[, .(trd_amount = sum(amount), stk_num = uniqueN(symbol)), by = .(date, industry)
    ][, .SD[trd_amount == max(trd_amount) & stk_num == max(stk_num), .(industry)], keyby = .(date)]
# Out:
#    date     industry
# 1  20120104 HDWRSEMI
# 2  20120106 HDWRSEMI
# 3  20120213 HDWRSEMI
# 4  20120216 HDWRSEMI
# 5  20120217 HDWRSEMI
# 6  20120220 HDWRSEMI
# 7  20120221 HDWRSEMI
# 8  20120222 HDWRSEMI
# 9  20120301 HDWRSEMI
# 10 20120302 HDWRSEMI
# 11 20120305 HDWRSEMI
# 12 20120307 HDWRSEMI
# 13 20120308 HDWRSEMI
# 14 20120418 HDWRSEMI
# 15 20120531 HDWRSEMI

# %% [markdown]
# #### *7. 每天涨幅超过5%、跌幅超过5%的股票各有多少？*

# %%
data[(close - pre_close)/pre_close > 0.05 | (close - pre_close)/pre_close < -0.05, .(symbol_amount = uniqueN(symbol)), by = .(tag = ifelse((close - pre_close)/pre_close > 0.05, "up5%ext", "down5%ext"), date)]
# Out:
#     tag       date     symbol_amount
# 1   up5%ext   20120227   47
# 2   up5%ext   20120228   50
# 3   up5%ext   20120319  109
# 4   up5%ext   20120117 1430
# 5   up5%ext   20120106   51
# 6   up5%ext   20120111   71
# 7   down5%ext 20120116  514
# 8   up5%ext   20120314   23
# 9   up5%ext   20120320   23
# 10  down5%ext 20120328 1112
# 11  up5%ext   20120405  248
# 12  up5%ext   20120510   52
# 13  down5%ext 20120625  275
# 14  up5%ext   20120605   25
# 15  up5%ext   20120613   99
# 16  up5%ext   20120518   41
# 17  up5%ext   20120215   83
# 18  up5%ext   20120109  558
# 19  up5%ext   20120625   27
# 20  up5%ext   20120110  504
# 21  down5%ext 20120621   48
# 22  up5%ext   20120418  112
# 23  up5%ext   20120522   53
# 24  down5%ext 20120314 1138
# 25  up5%ext   20120528  117
# 26  up5%ext   20120529   79
# 27  down5%ext 20120604  435
# 28  up5%ext   20120308   65
# 29  up5%ext   20120309   81
# 30  up5%ext   20120507  101
# ... ...       ...      ...
# 191 down5%ext 20120507  2
# 192 up5%ext   20120604  8
# 193 down5%ext 20120522  2
# 194 down5%ext 20120523  9
# 195 up5%ext   20120105 10
# 196 down5%ext 20120619 10
# 197 down5%ext 20120611  8
# 198 down5%ext 20120607 11
# 199 down5%ext 20120316  7
# 200 down5%ext 20120217  3
# 201 down5%ext 20120130  8
# 202 down5%ext 20120425 19
# 203 down5%ext 20120111  3
# 204 down5%ext 20120530  2
# 205 down5%ext 20120411  2
# 206 down5%ext 20120301  3
# 207 down5%ext 20120618  2
# 208 down5%ext 20120216  2
# 209 down5%ext 20120220  1
# 210 down5%ext 20120416 11
# 211 down5%ext 20120319  4
# 212 down5%ext 20120221  1
# 213 down5%ext 20120601  5
# 214 down5%ext 20120420  5
# 215 down5%ext 20120405  5
# 216 down5%ext 20120406  2
# 217 down5%ext 20120410  6
# 218 down5%ext 20120412  1
# 219 down5%ext 20120308  1
# 220 down5%ext 20120109  1

# %% [markdown]
# #### *8. 每天涨幅前10的股票的总成交额和跌幅前10的股票的总成交额比例是多少？*

# %%
data[, .SD, keyby = .(date, violet = ((close - pre_close)/pre_close))
    ][, .(ratio = sum(amount[1:10])/sum(amount[(.N-10):.N])), by = date]
# Out:
#     date     ratio
# 1   20120104 0.4872509
# 2   20120105 0.4865540
# 3   20120106 0.6407234
# 4   20120109 0.3406203
# 5   20120110 1.7591140
# 6   20120111 0.6983067
# 7   20120112 2.2585934
# 8   20120113 0.2505291
# 9   20120116 1.2686356
# 10  20120117 0.3230138
# 11  20120118 0.5485787
# 12  20120119 1.8044949
# 13  20120120 2.4861882
# 14  20120130 1.8265976
# 15  20120131 0.5960954
# 16  20120201 1.1580731
# 17  20120202 1.1295453
# 18  20120203 1.4241718
# 19  20120206 1.5341702
# 20  20120207 0.5099599
# 21  20120208 0.8986844
# 22  20120209 0.7990737
# 23  20120210 0.2070284
# 24  20120213 0.6177778
# 25  20120214 1.1275207
# 26  20120215 1.1107586
# 27  20120216 0.3230486
# 28  20120217 0.2261468
# 29  20120220 0.5446072
# 30  20120221 0.4907636
# ... ...      ...
# 88  20120518 1.6580088
# 89  20120521 0.5115863
# 90  20120522 0.6631375
# 91  20120523 0.2716677
# 92  20120524 1.7208419
# 93  20120525 0.3971556
# 94  20120528 0.3466847
# 95  20120529 0.5596081
# 96  20120530 0.4372633
# 97  20120531 0.8929417
# 98  20120601 0.5034967
# 99  20120604 0.4529167
# 100 20120605 0.6617468
# 101 20120606 1.0588649
# 102 20120607 0.9072479
# 103 20120608 0.6645945
# 104 20120611 1.1998855
# 105 20120612 1.1659419
# 106 20120613 1.1036932
# 107 20120614 0.7335171
# 108 20120615 1.4193996
# 109 20120618 1.7240957
# 110 20120619 1.0970128
# 111 20120620 1.4970851
# 112 20120621 0.7537146
# 113 20120625 1.2432310
# 114 20120626 0.7389795
# 115 20120627 1.4498633
# 116 20120628 1.1150186
# 117 20120629 0.7919075

# %% [markdown]
# #### *9. 每天开盘涨停的股票与收盘涨停的股票各有多少？（涨停按照收益率超过1.5%的标准计算）*

# %%
data[(close/pre_close - 1) > 0.015 | (open/pre_close - 1) > 0.015, .SD, by = .(date, symbol, tag = ifelse((close/pre_close - 1) > 0.015, "closelimit", "openlimit"))
    ][, .(symbol_amount = uniqueN(symbol)), keyby = .(date, tag)]
# Out:
#     date     tag        symbol_amount
# 1   20120104 closelimit   70
# 2   20120104 openlimit   297
# 3   20120105 closelimit   60
# 4   20120105 openlimit    22
# 5   20120106 closelimit  743
# 6   20120106 openlimit    29
# 7   20120109 closelimit 2142
# 8   20120109 openlimit     3
# 9   20120110 closelimit 2125
# 10  20120110 openlimit     1
# 11  20120111 closelimit  354
# 12  20120111 openlimit    26
# 13  20120112 closelimit  258
# 14  20120112 openlimit    20
# 15  20120113 closelimit   56
# 16  20120113 openlimit    34
# 17  20120116 closelimit   40
# 18  20120116 openlimit    13
# 19  20120117 closelimit 2180
# 20  20120118 closelimit   93
# 21  20120118 openlimit   116
# 22  20120119 closelimit  805
# 23  20120119 openlimit    21
# 24  20120120 closelimit  958
# 25  20120120 openlimit    44
# 26  20120130 closelimit  246
# 27  20120130 openlimit    84
# 28  20120131 closelimit  353
# 29  20120131 openlimit    16
# 30  20120201 closelimit  191
# ... ...      ...        ...
# 204 20120608 closelimit  210
# 205 20120608 openlimit   290
# 206 20120611 closelimit 1303
# 207 20120611 openlimit    17
# 208 20120612 closelimit  258
# 209 20120612 openlimit    15
# 210 20120613 closelimit 1261
# 211 20120613 openlimit     8
# 212 20120614 closelimit  217
# 213 20120614 openlimit    14
# 214 20120615 closelimit  341
# 215 20120615 openlimit    22
# 216 20120618 closelimit  663
# 217 20120618 openlimit    34
# 218 20120619 closelimit  221
# 219 20120619 openlimit    12
# 220 20120620 closelimit  313
# 221 20120620 openlimit    24
# 222 20120621 closelimit  145
# 223 20120621 openlimit    10
# 224 20120625 closelimit   87
# 225 20120625 openlimit    16
# 226 20120626 closelimit  326
# 227 20120626 openlimit     8
# 228 20120627 closelimit  293
# 229 20120627 openlimit    18
# 230 20120628 closelimit  162
# 231 20120628 openlimit    54
# 232 20120629 closelimit  961
# 233 20120629 openlimit     5

# %% [markdown]
# #### *10. 每天统计最近3天出现过开盘涨停、跌停的股票各有多少只？*

# %%
data[(close/pre_close - 1) > 0.015 | (open/pre_close - 1) > 0.015, .SD, by = .(date, symbol, tag = ifelse((close/pre_close - 1) > 0.015, "closelimit", "openlimit"))
    ][, uniqueN(symbol), keyby = .(tag, date)
    ][, .(symbol_amount = {
        a <- vector()
        for (i in 4:.N) {
            a[i] <- sum(V1[(i-3):(i-1)])
        }
        a
    }, date), by = .(tag)]
# Out:
#     tag        symbol_amount date
# 1   closelimit   NA          20120104
# 2   closelimit   NA          20120105
# 3   closelimit   NA          20120106
# 4   closelimit  873          20120109
# 5   closelimit 2945          20120110
# 6   closelimit 5010          20120111
# 7   closelimit 4621          20120112
# 8   closelimit 2737          20120113
# 9   closelimit  668          20120116
# 10  closelimit  354          20120117
# 11  closelimit 2276          20120118
# 12  closelimit 2313          20120119
# 13  closelimit 3078          20120120
# 14  closelimit 1856          20120130
# 15  closelimit 2009          20120131
# 16  closelimit 1557          20120201
# 17  closelimit  790          20120202
# 18  closelimit 1975          20120203
# 19  closelimit 2824          20120206
# 20  closelimit 3249          20120207
# 21  closelimit 1921          20120208
# 22  closelimit 2631          20120209
# 23  closelimit 2509          20120210
# 24  closelimit 2818          20120213
# 25  closelimit 1703          20120214
# 26  closelimit 1556          20120215
# 27  closelimit 2261          20120216
# 28  closelimit 1813          20120217
# 29  closelimit 1660          20120220
# 30  closelimit  856          20120221
# ... ...        ...           ...
# 204 openlimit   42           20120518
# 205 openlimit   45           20120521
# 206 openlimit   66           20120522
# 207 openlimit   99           20120523
# 208 openlimit   95           20120524
# 209 openlimit   76           20120525
# 210 openlimit   50           20120528
# 211 openlimit   43           20120529
# 212 openlimit   37           20120530
# 213 openlimit   37           20120531
# 214 openlimit   37           20120601
# 215 openlimit   62           20120604
# 216 openlimit   55           20120605
# 217 openlimit   89           20120606
# 218 openlimit   88           20120607
# 219 openlimit  391           20120608
# 220 openlimit  644           20120611
# 221 openlimit  623           20120612
# 222 openlimit  322           20120613
# 223 openlimit   40           20120614
# 224 openlimit   37           20120615
# 225 openlimit   44           20120618
# 226 openlimit   70           20120619
# 227 openlimit   68           20120620
# 228 openlimit   70           20120621
# 229 openlimit   46           20120625
# 230 openlimit   50           20120626
# 231 openlimit   34           20120627
# 232 openlimit   42           20120628
# 233 openlimit   80           20120629

# %% [markdown]
# #### *11. 股票每天的成交额变化率和收益率的相关性如何？*

# %%
data[, .(amount_change = {
    a <- vector()
    for (i in 2:.N) {
        a[i] <- amount[i]/amount[i-1] - 1
    }
    a
    }, ret = close/pre_close - 1, symbol = symbol)
    ][is.finite(amount_change), na.omit(.SD)
    ][, cor(amount_change, ret)]
# Out:
# [1] 0.163331

# %% [markdown]
# #### *12. 每天每个行业的总成交额变化率和行业收益率的相关性如何？*

# %%
data[, .(ind_amount = sum(amount), weight = capt/sum(capt), ret = close/pre_close - 1), keyby = .(date, industry)
    ][, .(ind_ret = sum(weight * ret), ind_amount = ind_amount), keyby = .(industry, date)
    ][, unique(.SD)
    ][, .(ind_amount_change = {
        a <- vector()
        for (i in 2:.N) {
            a[i] <- ind_amount[i]/ind_amount[i-1] - 1
        }
        a
    }, ind_ret = ind_ret), keyby = .(industry)
    ][!is.na(ind_amount_change), cor(ind_amount_change, ind_ret)]
# Out:
# [1] 0.3942165

# %% [markdown]
# #### *13. 每天市场的总成交额变化率和市场收益率相关性如何？*

# %%
data[, .(mkt_amount = sum(amount), weight = capt/sum(capt), ret = close/pre_close - 1), keyby = date
    ][, .(mkt_ret = sum(weight * ret), mkt_amount = mkt_amount), keyby = date
    ][, unique(.SD)
    ][, .(mkt_amount_change = {
        a <- vector()
        for (i in 2:.N) {
            a[i] <- mkt_amount[i]/mkt_amount[i-1]-1
        }
        a
    }, mkt_ret = mkt_ret)
    ][!is.na(mkt_amount_change), cor(mkt_amount_change, mkt_ret)]
# Out:
# [1] 0.4424592

# %% [markdown]
# #### *14. 每天市场的总成交额的变化率和所有股票收益率的标准差相关性如何？*

# %%
data[, .(mkt_amount = sum(amount), ret = close/pre_close - 1, symbol = symbol), keyby = date
    ][, .(ret_sd = unique(sd(ret)), mkt_amount = unique(mkt_amount)), keyby = date
    ][, .(mkt_amount_change = {
        a <- vector()
        for (i in 2:.N) {
            a[i] <- mkt_amount[i]/mkt_amount[i-1] - 1
        }
        a
    }, ret_sd = ret_sd)
    ][!is.na(mkt_amount_change), cor(mkt_amount_change, ret_sd)]
# Out:
# [1] -0.1913893

# %% [markdown]
# #### *15. 每天每个行业的总成交额变化率和行业内股票收益率的标准差相关性如何？*

# %%
data[, .(ind_amount = sum(amount), ret = close/pre_close - 1, symbol = symbol), keyby = .(industry, date)
    ][, .(ind_ret_sd = unique(sd(ret)), ind_amount = unique(ind_amount)), keyby = .(industry, date)
    ][, .(ind_amount_change = {
        a <- vector()
        for (i in 2:.N) {
            a[i] <- ind_amount[i]/ind_amount[i-1] - 1
        }
        a
    }, ind_ret_sd = ind_ret_sd), keyby = industry
    ][!is.na(ind_amount_change), cor(ind_ret_sd, ind_amount_change)]
# Out:
# [1] 0.1043456

# %% [markdown]
# #### *16. 上证50、沪深300、中证500指数成分股中，沪股和深股各有多少？*

# %%
list(data[index_w50 > 0, .(stkcd_amount = uniqueN(symbol), type = "index_w50"), by = .(type = ifelse(str_detect(symbol, "SH"), "SH", "SZ"))], 
    data[index_w300 > 0, .(stkcd_amount = uniqueN(symbol), type = "index_w300"), by = .(type = ifelse(str_detect(symbol, "SH"), "SH", "SZ"))], 
    data[index_w500 > 0, .(stkcd_amount = uniqueN(symbol), type = "index_w500"), by = .(type = ifelse(str_detect(symbol, "SH"), "SH", "SZ"))]) %>% rbindlist()
# Out:
#   type stkcd_amount type
# 1 SH    54          index_w50
# 2 SH   205          index_w300
# 3 SZ    95          index_w300
# 4 SH   297          index_w500
# 5 SZ   248          index_w500

# %% [markdown]
# #### *17. 上证50、沪深300、中证500指数成分股中，行业分布如何？*

# %%
list(data[index_w50 > 0, .(stkcd_amount = uniqueN(symbol), type = "index_w50"), by = .(industry)], 
    data[index_w300 > 0, .(stkcd_amount = uniqueN(symbol), type = "index_w300"), by = .(industry)], 
    data[index_w500 > 0, .(stkcd_amount = uniqueN(symbol), type = "index_w500"), by = .(industry)]) %>% rbindlist()
# Out:
#     industry stkcd_amount type
# 1   BANKS    11           index_w50
# 2   MTLMIN   10           index_w50
# 3   ENERGY    7           index_w50
# 4   DVFININS  6           index_w50
# 5   MACH      4           index_w50
# 6   REALEST   2           index_w50
# 7   HDWRSEMI  1           index_w50
# 8   TRDDIST   1           index_w50
# 9   CNSTENG   3           index_w50
# 10  ELECEQP   1           index_w50
# 11  AUTO      1           index_w50
# 12  BEV       1           index_w50
# 13  CONMAT    1           index_w50
# 14  UTILITIE  1           index_w50
# 15  RDRLTRAN  1           index_w50
# 16  AIRLINE   1           index_w50
# 17  CHEM      1           index_w50
# 18  MARINE    1           index_w50
# 19  BANKS    16           index_w300
# 20  MTLMIN   36           index_w300
# 21  UTILITIE 12           index_w300
# 22  RDRLTRAN  5           index_w300
# 23  MARINE    4           index_w300
# 24  ENERGY   24           index_w300
# 25  AIRLINE   4           index_w300
# 26  DVFININS 18           index_w300
# 27  MACH     20           index_w300
# 28  MEDIA     3           index_w300
# 29  REALEST  13           index_w300
# 30  HDWRSEMI 10           index_w300
# ... ...      ...          ...
# 50  AUTO     20           index_w500
# 51  UTILITIE 24           index_w500
# 52  MTLMIN   34           index_w500
# 53  AERODEF   2           index_w500
# 54  REALEST  44           index_w500
# 55  CONSSERV  8           index_w500
# 56  TRDDIST   9           index_w500
# 57  BEV       7           index_w500
# 58  HOUSEDUR 12           index_w500
# 59  LEISLUX  22           index_w500
# 60  CHEM     52           index_w500
# 61  ELECEQP  28           index_w500
# 62  MATERIAL 12           index_w500
# 63  MACH     34           index_w500
# 64  FOODPROD 27           index_w500
# 65  HEALTH   43           index_w500
# 66  HDWRSEMI 44           index_w500
# 67  MARINE    4           index_w500
# 68  MEDIA     9           index_w500
# 69  RETAIL   17           index_w500
# 70  ENERGY   11           index_w500
# 71  CONMAT   11           index_w500
# 72  INDCONG   5           index_w500
# 73  BLDPROD   5           index_w500
# 74  CNSTENG  14           index_w500
# 75  AIRLINE   4           index_w500
# 76  SOFTWARE 11           index_w500
# 77  PERSPRD   6           index_w500
# 78  DVFININS  1           index_w500
# 79  COMSERV   5           index_w500

# %% [markdown]
# #### *18. 每天上证50、沪深300、中证500指数成分股的总成交额各是多少？*

# %%
list(data[index_w50 > 0, .(amount = sum(amount) %>% unique(), type = "index_w50"), by = .(date)], 
    data[index_w300 > 0, .(amount = sum(amount) %>% unique(), type = "index_w300"), by = .(date)], 
    data[index_w500 > 0, .(amount = sum(amount) %>% unique(), type = "index_w500"), by = .(date)]) %>% rbindlist()
# Out:
#     date     amount      type
# 1   20120104 11372037211 index_w50
# 2   20120105 15174601949 index_w50
# 3   20120106 11457969686 index_w50
# 4   20120109 19783087939 index_w50
# 5   20120110 25840613156 index_w50
# 6   20120111 17961005017 index_w50
# 7   20120112 16699936305 index_w50
# 8   20120113 16871980689 index_w50
# 9   20120116 12436137122 index_w50
# 10  20120117 24730323911 index_w50
# 11  20120118 23518166213 index_w50
# 12  20120119 21927842113 index_w50
# 13  20120120 21921052047 index_w50
# 14  20120130 18446545356 index_w50
# 15  20120131 13239423407 index_w50
# 16  20120201 14193726576 index_w50
# 17  20120202 17836381969 index_w50
# 18  20120203 19129273031 index_w50
# 19  20120206 16256800163 index_w50
# 20  20120207 14397210154 index_w50
# 21  20120208 22752042078 index_w50
# 22  20120209 21389844651 index_w50
# 23  20120210 20972221791 index_w50
# 24  20120213 16994977747 index_w50
# 25  20120214 13194356723 index_w50
# 26  20120215 19165036567 index_w50
# 27  20120216 17006014781 index_w50
# 28  20120217 12347860075 index_w50
# 29  20120220 18885764023 index_w50
# 30  20120221 13834849720 index_w50
# ... ...      ...         ...
# 322 20120607 24059754834 index_w500
# 323 20120608 24632330712 index_w500
# 324 20120611 26395399785 index_w500
# 325 20120612 23442262200 index_w500
# 326 20120613 29468855604 index_w500
# 327 20120614 30953322837 index_w500
# 328 20120615 27690673635 index_w500
# 329 20120618 26269674861 index_w500
# 330 20120619 29309582210 index_w500
# 331 20120620 23665268119 index_w500
# 332 20120621 23639187187 index_w500
# 333 20120625 22532215538 index_w500
# 334 20120626 21483353140 index_w500
# 335 20120627 21639398881 index_w500
# 336 20120628 22602437253 index_w500
# 337 20120629 23306389586 index_w500
# 338 20120104 14524793317 index_w500
# 339 20120105 15625211500 index_w500
# 340 20120106 13828890301 index_w500
# 341 20120109 19513699717 index_w500
# 342 20120110 30514518911 index_w500
# 343 20120111 26734594075 index_w500
# 344 20120112 23360250650 index_w500
# 345 20120113 22903605941 index_w500
# 346 20120116 14770460574 index_w500
# 347 20120117 24190587967 index_w500
# 348 20120118 25906635875 index_w500
# 349 20120119 19281495124 index_w500
# 350 20120120 18759755175 index_w500
# 351 20120130 15801755404 index_w500

# %% [markdown]
# #### *19. 上证50、沪深300、中证500指数日收益率的历史波动率是多少？*

# %%
list(data[, .(index_ret = sum(index_w50 * (close/pre_close - 1))), keyby = .(date)
        ][, .(vol = sd(index_ret), type = "index_w50")],
    data[, .(index_ret = sum(index_w300 * (close/pre_close - 1))), keyby = .(date)
        ][, .(vol = sd(index_ret), type = "index_w300")],
    data[, .(index_ret = sum(index_w500 * (close/pre_close - 1))), keyby = .(date)
        ][, .(vol = sd(index_ret), type = "index_w500")]) %>% rbindlist()
# Out:
#   vol        type
# 1 0.01234205 index_w50
# 2 0.01336797 index_w300
# 3 0.01607531 index_w500

# %% [markdown]
# #### *20. 上证50、沪深300、中证500指数日收益率的相关系数矩阵？*

# %%
data[, .(index_w50_ret = sum(index_w50 * (close/pre_close - 1)), index_w300_ret = sum(index_w300 * (close/pre_close - 1)), index_w500_ret = sum(index_w500 * (close/pre_close - 1))), keyby = date
    ][, cor(.SD[, -1])]
# Out:
#                index_w50_ret index_w300_ret index_w500_ret
# index_w50_ret  1.0000000     0.9760849      0.8476975
# index_w300_ret 0.9760849     1.0000000      0.9333580
# index_w500_ret 0.8476975     0.9333580      1.0000000

# %% [markdown]
# #### *21. 上证50、沪深300、去除上证50的沪深300指数日收益率的相关系数矩阵？*

# %%
data[, .(index_w50_ret = sum(index_w50 * (close/pre_close - 1)), index_w300_ret = sum(index_w300 * (close/pre_close - 1)), index_w300_50 = ifelse(index_w50 == 0 & index_w300 > 0, index_w300, 0), close = close, pre_close = pre_close), keyby = date       ][, .(index_w50_ret = unique(index_w50_ret), index_w300_ret = unique(index_w300_ret), index_w300_50_ret = sum(index_w300_50 * (close/pre_close - 1)) %>% unique()), keyby = date
    ][, cor(.SD[, -1])]
# Out:
#                   index_w50_ret index_w300_ret index_w300_50_ret
# index_w50_ret     1.0000000     0.9760849      0.9294381
# index_w300_ret    0.9760849     1.0000000      0.9874054
# index_w300_50_ret 0.9294381     0.9874054      1.0000000

# %% [markdown]
# #### *22. 每天沪深300指数成分占比最大的10只股票是哪些？*

# %%
data[order(date, index_w300), .(symbol = symbol[1:10]), by = .(date)]
# Out:
#      date     symbol
# 1    20120104 600004.SH
# 2    20120104 600006.SH
# 3    20120104 600007.SH
# 4    20120104 600011.SH
# 5    20120104 600012.SH
# 6    20120104 600017.SH
# 7    20120104 600018.SH
# 8    20120104 600020.SH
# 9    20120104 600021.SH
# 10   20120104 600022.SH
# 11   20120105 600004.SH
# 12   20120105 600006.SH
# 13   20120105 600007.SH
# 14   20120105 600011.SH
# 15   20120105 600012.SH
# 16   20120105 600017.SH
# 17   20120105 600018.SH
# 18   20120105 600020.SH
# 19   20120105 600021.SH
# 20   20120105 600022.SH
# 21   20120106 600004.SH
# 22   20120106 600006.SH
# 23   20120106 600007.SH
# 24   20120106 600011.SH
# 25   20120106 600012.SH
# 26   20120106 600017.SH
# 27   20120106 600018.SH
# 28   20120106 600020.SH
# 29   20120106 600021.SH
# 30   20120106 600022.SH
# ...  ...      ...
# 1141 20120627 600004.SH
# 1142 20120627 600006.SH
# 1143 20120627 600007.SH
# 1144 20120627 600011.SH
# 1145 20120627 600012.SH
# 1146 20120627 600017.SH
# 1147 20120627 600018.SH
# 1148 20120627 600020.SH
# 1149 20120627 600021.SH
# 1150 20120627 600022.SH
# 1151 20120628 600004.SH
# 1152 20120628 600006.SH
# 1153 20120628 600007.SH
# 1154 20120628 600011.SH
# 1155 20120628 600012.SH
# 1156 20120628 600017.SH
# 1157 20120628 600018.SH
# 1158 20120628 600020.SH
# 1159 20120628 600021.SH
# 1160 20120628 600022.SH
# 1161 20120629 600004.SH
# 1162 20120629 600006.SH
# 1163 20120629 600007.SH
# 1164 20120629 600011.SH
# 1165 20120629 600012.SH
# 1166 20120629 600017.SH
# 1167 20120629 600018.SH
# 1168 20120629 600020.SH
# 1169 20120629 600021.SH
# 1170 20120629 600022.SH

# %% [markdown]
# #### *23. 各个行业的平均每日股票数量从大到小排序是什么？*

# %%
data[, .(stkcd_amount = uniqueN(symbol)), keyby = .(date, industry)
    ][order(date, -stkcd_amount)]
# Out:
#      date     industry stkcd_amount
# 1    20120104 HDWRSEMI 224
# 2    20120104 CHEM     219
# 3    20120104 MACH     201
# 4    20120104 HEALTH   172
# 5    20120104 ELECEQP  131
# 6    20120104 REALEST  131
# 7    20120104 MTLMIN   128
# 8    20120104 LEISLUX  106
# 9    20120104 FOODPROD  99
# 10   20120104 AUTO      85
# 11   20120104 SOFTWARE  75
# 12   20120104 RETAIL    74
# 13   20120104 UTILITIE  74
# 14   20120104 HOUSEDUR  61
# 15   20120104 ENERGY    57
# 16   20120104 RDRLTRAN  56
# 17   20120104 CNSTENG   54
# 18   20120104 MATERIAL  48
# 19   20120104 CONMAT    37
# 20   20120104 TRDDIST   36
# 21   20120104 CONSSERV  34
# 22   20120104 BEV       30
# 23   20120104 BLDPROD   28
# 24   20120104 COMSERV   27
# 25   20120104 PERSPRD   25
# 26   20120104 DVFININS  23
# 27   20120104 MEDIA     22
# 28   20120104 BANKS     16
# 29   20120104 INDCONG   13
# 30   20120104 AIRLINE   12
# ...  ...      ...      ...
# 3715 20120629 MACH     208
# 3716 20120629 HEALTH   183
# 3717 20120629 ELECEQP  138
# 3718 20120629 MTLMIN   133
# 3719 20120629 REALEST  132
# 3720 20120629 LEISLUX  110
# 3721 20120629 FOODPROD 103
# 3722 20120629 AUTO      90
# 3723 20120629 SOFTWARE  89
# 3724 20120629 UTILITIE  75
# 3725 20120629 RETAIL    74
# 3726 20120629 HOUSEDUR  63
# 3727 20120629 ENERGY    59
# 3728 20120629 CNSTENG   57
# 3729 20120629 RDRLTRAN  57
# 3730 20120629 MATERIAL  51
# 3731 20120629 CONMAT    37
# 3732 20120629 TRDDIST   36
# 3733 20120629 CONSSERV  33
# 3734 20120629 BEV       31
# 3735 20120629 COMSERV   29
# 3736 20120629 BLDPROD   27
# 3737 20120629 MEDIA     26
# 3738 20120629 DVFININS  25
# 3739 20120629 PERSPRD   25
# 3740 20120629 BANKS     16
# 3741 20120629 AIRLINE   13
# 3742 20120629 AERODEF   12
# 3743 20120629 MARINE    12
# 3744 20120629 INDCONG   11

# %% [markdown]
# #### *24. 每个行业每天成交额最大的一只股票代码是什么？*

# %%
data[order(-amount), .(symbol = symbol[1]), keyby = .(date, industry)]
# Out:
# 13    20120104 AUTO     000800.SZ  859985682
# 14    20120104 AUTO     600741.SH  859985682
# 15    20120104 AUTO     600760.SH  859985682
# 16    20120104 BANKS    600036.SH 2089068190
# 17    20120104 BANKS    601166.SH 2089068190
# 18    20120104 BANKS    600016.SH 2089068190
# 19    20120104 BANKS    600000.SH 2089068190
# 20    20120104 BANKS    601818.SH 2089068190
# 21    20120104 BEV      600519.SH 1869108456
# 22    20120104 BEV      000858.SZ 1869108456
# 23    20120104 BEV      000568.SZ 1869108456
# 24    20120104 BEV      002646.SZ 1869108456
# 25    20120104 BEV      600809.SH 1869108456
# 26    20120104 BLDPROD  601636.SH  133949358
# 27    20120104 BLDPROD  002631.SZ  133949358
# 28    20120104 BLDPROD  000786.SZ  133949358
# 29    20120104 BLDPROD  002011.SZ  133949358
# 30    20120104 BLDPROD  002162.SZ  133949358
# ...   ...      ...      ...       ...
# 18691 20120629 RDRLTRAN 601006.SH  695894990
# 18692 20120629 RDRLTRAN 601880.SH  695894990
# 18693 20120629 RDRLTRAN 600077.SH  695894990
# 18694 20120629 RDRLTRAN 000828.SZ  695894990
# 18695 20120629 RDRLTRAN 002682.SZ  695894990
# 18696 20120629 REALEST  600048.SH 1569178531
# 18697 20120629 REALEST  600383.SH 1569178531
# 18698 20120629 REALEST  000014.SZ 1569178531
# 18699 20120629 REALEST  600113.SH 1569178531
# 18700 20120629 REALEST  600606.SH 1569178531
# 18701 20120629 RETAIL   600739.SH  760465188
# 18702 20120629 RETAIL   002024.SZ  760465188
# 18703 20120629 RETAIL   600315.SH  760465188
# 18704 20120629 RETAIL   600830.SH  760465188
# 18705 20120629 RETAIL   600120.SH  760465188
# 18706 20120629 SOFTWARE 300104.SZ  820995303
# 18707 20120629 SOFTWARE 002230.SZ  820995303
# 18708 20120629 SOFTWARE 002063.SZ  820995303
# 18709 20120629 SOFTWARE 600588.SH  820995303
# 18710 20120629 SOFTWARE 002474.SZ  820995303
# 18711 20120629 TRDDIST  600366.SH  837608599
# 18712 20120629 TRDDIST  600735.SH  837608599
# 18713 20120629 TRDDIST  600546.SH  837608599
# 18714 20120629 TRDDIST  600605.SH  837608599
# 18715 20120629 TRDDIST  600058.SH  837608599
# 18716 20120629 UTILITIE 600011.SH  849040464
# 18717 20120629 UTILITIE 600027.SH  849040464
# 18718 20120629 UTILITIE 300262.SZ  849040464
# 18719 20120629 UTILITIE 000543.SZ  849040464
# 18720 20120629 UTILITIE 600292.SH  849040464

# %% [markdown]
# #### *27. 每个行业每天成交额超过该行业中股票成交额80%分位数的股票的平均收益率是多少？*

# %%
data[, .(symbol = symbol, ret = close/pre_close - 1, amount = amount, industry, date)
    ][, .SD[amount > quantile(amount, 0.8)], keyby = .(date, industry)
    ][, .(aver_ret = mean(ret)), keyby = .(date, industry)]
# Out:
#      date     industry aver_ret
# 1    20120104 AERODEF   0.005714392
# 2    20120104 AIRLINE  -0.024726379
# 3    20120104 AUTO     -0.017813417
# 4    20120104 BANKS    -0.007846674
# 5    20120104 BEV      -0.056254460
# 6    20120104 BLDPROD  -0.031741456
# 7    20120104 CHEM     -0.032022583
# 8    20120104 CNSTENG  -0.026837227
# 9    20120104 COMSERV  -0.032827341
# 10   20120104 CONMAT   -0.032062156
# 11   20120104 CONSSERV -0.011679338
# 12   20120104 DVFININS -0.024368054
# 13   20120104 ELECEQP  -0.038778089
# 14   20120104 ENERGY   -0.020334131
# 15   20120104 FOODPROD -0.024361002
# 16   20120104 HDWRSEMI -0.026553495
# 17   20120104 HEALTH   -0.036054007
# 18   20120104 HOUSEDUR -0.012276507
# 19   20120104 INDCONG  -0.053868215
# 20   20120104 LEISLUX  -0.018373211
# 21   20120104 MACH     -0.027433184
# 22   20120104 MARINE   -0.065507276
# 23   20120104 MATERIAL -0.021444413
# 24   20120104 MEDIA    -0.006370580
# 25   20120104 MTLMIN   -0.019375133
# 26   20120104 PERSPRD  -0.004718465
# 27   20120104 RDRLTRAN -0.006130027
# 28   20120104 REALEST  -0.024603902
# 29   20120104 RETAIL   -0.005582094
# 30   20120104 SOFTWARE -0.032296053
# ...  ...      ...      ...
# 3715 20120629 AUTO      0.0074871892
# 3716 20120629 BANKS     0.0185906770
# 3717 20120629 BEV       0.0453462878
# 3718 20120629 BLDPROD   0.0186875392
# 3719 20120629 CHEM      0.0169914127
# 3720 20120629 CNSTENG   0.0001573158
# 3721 20120629 COMSERV   0.0281109505
# 3722 20120629 CONMAT    0.0038953946
# 3723 20120629 CONSSERV  0.0275466943
# 3724 20120629 DVFININS  0.0350693390
# 3725 20120629 ELECEQP   0.0119611508
# 3726 20120629 ENERGY    0.0224783421
# 3727 20120629 FOODPROD  0.0249979451
# 3728 20120629 HDWRSEMI  0.0175933822
# 3729 20120629 HEALTH    0.0308070142
# 3730 20120629 HOUSEDUR  0.0076037636
# 3731 20120629 INDCONG   0.0191099340
# 3732 20120629 LEISLUX   0.0075408840
# 3733 20120629 MACH      0.0052836943
# 3734 20120629 MARINE    0.0014933702
# 3735 20120629 MATERIAL  0.0153662285
# 3736 20120629 MEDIA     0.0379832275
# 3737 20120629 MTLMIN    0.0232648693
# 3738 20120629 PERSPRD  -0.0035252480
# 3739 20120629 RDRLTRAN  0.0210996985
# 3740 20120629 REALEST   0.0030814397
# 3741 20120629 RETAIL    0.0131100071
# 3742 20120629 SOFTWARE  0.0224472644
# 3743 20120629 TRDDIST  -0.0039941848
# 3744 20120629 UTILITIE  0.0074044491

# %% [markdown]
# #### *28. 每天成交额最大的10%的股票的平均收益率和成交额最小的10%的股票的平均收益率的相关系数是多少？*

# %%
data[, .(symbol = symbol, ret = close/pre_close - 1, amount = amount, date)
    ][, .(ret_aver = mean(ret)), keyby = .(date, tag = ifelse(amount > quantile(amount, 0.9), "max10%"，ifelse(amount < quantile(amount, 0.1), "min10%", "others")))
    ][, .SD[-3], keyby = .(date)]
# Out:
#     date     tag    ret_aver
# 1   20120104 max10% -1.810573e-02
# 2   20120104 min10% -1.790767e-02
# 3   20120105 max10% -2.175878e-02
# 4   20120105 min10% -3.048809e-02
# 5   20120106 max10%  5.994575e-03
# 6   20120106 min10%  4.869812e-03
# 21   20120106 AERODEF
# 22   20120106 BANKS
# 23   20120106 BEV
# 24   20120106 CONMAT
# 25   20120106 DVFININS
# 26   20120106 ENERGY
# 27   20120106 HOUSEDUR
# 28   20120106 INDCONG
# 29   20120106 MEDIA
# 30   20120106 MTLMIN
# ...  ...      ...
# 1384 20120628 AIRLINE
# 1385 20120628 BANKS
# 1386 20120628 BEV
# 1387 20120628 CNSTENG
# 1388 20120628 CONMAT
# 1389 20120628 DVFININS
# 1390 20120628 ENERGY
# 1391 20120628 FOODPROD
# 1392 20120628 HEALTH
# 1393 20120628 INDCONG
# 1394 20120628 MARINE
# 1395 20120628 MEDIA
# 1396 20120628 MTLMIN
# 1397 20120628 REALEST
# 1398 20120628 TRDDIST
# 1399 20120629 AERODEF
# 1400 20120629 AIRLINE
# 1401 20120629 BANKS
# 1402 20120629 BEV
# 1403 20120629 CNSTENG
# 1404 20120629 CONMAT
# 1405 20120629 DVFININS
# 1406 20120629 ENERGY
# 1407 20120629 FOODPROD
# 1408 20120629 HEALTH
# 1409 20120629 INDCONG
# 1410 20120629 MARINE
# 1411 20120629 MEDIA
# 1412 20120629 MTLMIN
# 1413 20120629 REALEST

# %% [markdown]
# #### *30. 每天每个股票对市场的超额收益率是多少？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, weight = capt/sum(capt), symbol), keyby = date
    ][, .(mkt_ret = sum(weight*stkcd_ret), stkcd_ret, symbol), keyby = date
    ][, .(alpha = coef(lm(stkcd_ret ~ mkt_ret))[1], beta = coef(lm(stkcd_ret ~ mkt_ret))[2], mkt_ret, stkcd_ret, symbol, date)
    ][, .(abnr_ret = stkcd_ret - alpha - beta * mkt_ret), keyby = .(date, symbol)]
# Out:
#        date     symbol    abnr_ret
# 1      20120104 000001.SZ -0.0075757072
# 2      20120104 000002.SZ  0.0012644428
# 3      20120104 000004.SZ -0.0022436150
# 4      20120104 000005.SZ  0.0200060760
# 5      20120104 000006.SZ  0.0102499784
# 6      20120104 000007.SZ  0.0701580517
# 7      20120104 000008.SZ -0.0302091320
# 8      20120104 000009.SZ -0.0533884194
# 9      20120104 000010.SZ  0.0200060760
# 10     20120104 000011.SZ  0.0021778750
# 11     20120104 000012.SZ -0.0285590454
# 12     20120104 000014.SZ -0.0004020873
# 13     20120104 000016.SZ  0.0168415190
# 14     20120104 000017.SZ  0.0126800687
# 15     20120104 000018.SZ -0.0017804164
# 16     20120104 000019.SZ  0.0018713610
# 17     20120104 000020.SZ -0.0008667893
# 18     20120104 000021.SZ  0.0083101696
# 19     20120104 000022.SZ  0.0157096206
# 20     20120104 000023.SZ -0.0220991872
# 21     20120104 000024.SZ  0.0083394093
# 22     20120104 000025.SZ  0.0129138774
# 23     20120104 000026.SZ  0.0200060760
# 24     20120104 000027.SZ  0.0085306662
# 25     20120104 000028.SZ -0.0254271793
# 26     20120104 000029.SZ  0.0016011680
# 27     20120104 000030.SZ -0.0299939240
# 28     20120104 000031.SZ  0.0068481813
# 29     20120104 000032.SZ -0.0234721849
# 30     20120104 000033.SZ  0.0006690594
# ...    ...      ...       ...
# 276871 20120629 601880.SH  0.0511490519
# 276872 20120629 601886.SH  0.0101183930
# 276873 20120629 601888.SH  0.0002288460
# 276874 20120629 601890.SH  0.0002189924
# 276875 20120629 601898.SH -0.0115132858
# 276876 20120629 601899.SH -0.0036532607
# 276877 20120629 601901.SH  0.0307145894
# 276878 20120629 601908.SH  0.0149124624
# 276879 20120629 601918.SH  0.0050492312
# 276880 20120629 601919.SH -0.0080124388
# 276881 20120629 601928.SH  0.0132320288
# 276882 20120629 601929.SH  0.0834219480
# 276883 20120629 601933.SH -0.0085235672
# 276884 20120629 601939.SH -0.0095138464
# 276885 20120629 601958.SH  0.0001458416
# 276886 20120629 601965.SH -0.0078975183
# 276887 20120629 601988.SH -0.0131493721
# 276888 20120629 601989.SH -0.0186311679
# 276889 20120629 601991.SH -0.0237627647
# 276890 20120629 601992.SH -0.0076033869
# 276891 20120629 601996.SH -0.0073184196
# 276892 20120629 601998.SH -0.0014796646
# 276893 20120629 601999.SH -0.0009261685
# 276894 20120629 603000.SH -0.0026201028
# 276895 20120629 603001.SH -0.0222513282
# 276896 20120629 603002.SH -0.0016704970
# 276897 20120629 603123.SH -0.0177060950
# 276898 20120629 603128.SH -0.0138303931
# 276899 20120629 603333.SH -0.0122636465
# 276900 20120629 603366.SH  0.0044671340

# %% [markdown]
# #### *31. 每天每个股票对市场去除自身的超额收益率是多少？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, symbol, weight =  capt/(sum(capt) - capt)),keyby = date
    ][, .(mkt_ret = sum(weight*stkcd_ret), stkcd_ret, symbol), keyby = date
    ][, .(alpha = coef(lm(stkcd_ret ~ mkt_ret))[1], beta = coef(lm(stkcd_ret ~ mkt_ret))[2], mkt_ret, stkcd_ret, symbol, date)
    ][, .(abnr_ret = stkcd_ret - alpha - beta * mkt_ret), keyby = .(date, symbol)]
# Out:
#        date     symbol    abnr_ret
# 1      20120104 000001.SZ -0.0077629463
# 2      20120104 000002.SZ  0.0010772037
# 3      20120104 000004.SZ -0.0024308541
# 4      20120104 000005.SZ  0.0198188369
# 5      20120104 000006.SZ  0.0100627393
# 6      20120104 000007.SZ  0.0699708126
# 7      20120104 000008.SZ -0.0303963711
# 8      20120104 000009.SZ -0.0535756585
# 9      20120104 000010.SZ  0.0198188369
# 10     20120104 000011.SZ  0.0019906359
# 11     20120104 000012.SZ -0.0287462845
# 12     20120104 000014.SZ -0.0005893264
# 13     20120104 000016.SZ  0.0166542799
# 14     20120104 000017.SZ  0.0124928296
# 15     20120104 000018.SZ -0.0019676555
# 16     20120104 000019.SZ  0.0016841219
# 17     20120104 000020.SZ -0.0010540284
# 18     20120104 000021.SZ  0.0081229305
# 19     20120104 000022.SZ  0.0155223815
# 20     20120104 000023.SZ -0.0222864263
# 21     20120104 000024.SZ  0.0081521702
# 22     20120104 000025.SZ  0.0127266383
# 23     20120104 000026.SZ  0.0198188369
# 24     20120104 000027.SZ  0.0083434271
# 25     20120104 000028.SZ -0.0256144184
# 26     20120104 000029.SZ  0.0014139289
# 27     20120104 000030.SZ -0.0301811631
# 28     20120104 000031.SZ  0.0066609422
# 29     20120104 000032.SZ -0.0236594240
# 30     20120104 000033.SZ  0.0004818203
# ...    ...      ...       ...
# 276871 20120629 601880.SH  0.0511385301
# 28     20120104 000031.SZ  0.0062626995
# 29     20120104 000032.SZ -0.0136298917
# 30     20120104 000033.SZ -0.0015276985
# ...    ...      ...       ...
# 276871 20120629 601880.SH  0.0572329820
# 276872 20120629 601886.SH  0.0185121206
# 276873 20120629 601888.SH  0.0009643195
# 276874 20120629 601890.SH  0.0082132767
# 276875 20120629 601898.SH -0.0116906597
# 276876 20120629 601899.SH -0.0009383523
# 276877 20120629 601901.SH  0.0098424646
# 276878 20120629 601908.SH  0.0167636571
# 276879 20120629 601918.SH  0.0048718573
# 276880 20120629 601919.SH  0.0046550504
# 276881 20120629 601928.SH  0.0123097446
# 276882 20120629 601929.SH  0.0824996639
# 276883 20120629 601933.SH  0.0040139573
# 276884 20120629 601939.SH -0.0052107981
# 276885 20120629 601958.SH  0.0028607500
# 276886 20120629 601965.SH -0.0001452526
# 276887 20120629 601988.SH -0.0088463238
# 276888 20120629 601989.SH -0.0106368836
# 276889 20120629 601991.SH -0.0099391694
# 276890 20120629 601992.SH -0.0023819674
# 276891 20120629 601996.SH -0.0014381715
# 276892 20120629 601998.SH  0.0028233837
# 276893 20120629 601999.SH -0.0018484526
# 276894 20120629 603000.SH -0.0035423870
# 276895 20120629 603001.SH -0.0165947883
# 276896 20120629 603002.SH  0.0037459538
# 276897 20120629 603123.SH -0.0118338171
# 276898 20120629 603128.SH -0.0160168439
# 276899 20120629 603333.SH -0.0056460293
# 276900 20120629 603366.SH  0.0063183287

# %% [markdown]
# #### *34. 每个股票每天对市场的超额收益率与对行业的超额收益率的相关系数如何？*

# %%
mkt <- data[, .(stkcd_ret = close/pre_close - 1, weight = capt/sum(capt), symbol), keyby = date
    ][, .(mkt_ret = sum(weight/100*stkcd_ret), stkcd_ret, symbol), keyby = date
    ][, .(alpha = coef(lm(stkcd_ret ~ mkt_ret))[1], beta = coef(lm(stkcd_ret ~ mkt_ret))[2], mkt_ret, stkcd_ret, symbol, date)
    ][, .(abnr_mkt_ret = stkcd_ret - alpha - beta * mkt_ret), keyby = .(date, symbol)]
ind <- data[, .(stkcd_ret = close/pre_close - 1, symbol, weight = capt/sum(capt)), keyby = .(industry,date)
    ][, .(ind_ret = sum(weight/100*stkcd_ret), stkcd_ret, symbol), keyby = .(industry, date)
    ][, .(alpha = coef(lm(stkcd_ret ~ ind_ret))[1], beta = coef(lm(stkcd_ret ~ ind_ret))[2], ind_ret, stkcd_ret, symbol, date), keyby = .(industry)
    ][, .(abnr_ind_ret = stkcd_ret - alpha - beta * ind_ret), keyby = .(date, symbol)]
cor(mkt[ind, on = .(date, symbol)][, 3:4])
rm(mkt, ind)
# Out:
#              abnr_mkt_ret abnr_ind_ret
# abnr_mkt_ret 1.000000     0.946769
# abnr_ind_ret 0.946769     1.000000

# %% [markdown]
# #### *35. 每天有哪些行业的平均收益率超过市场平均收益率？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, symbol, ind_weight = capt/sum(capt), capt), keyby = .(industry,date)
    ][, .(ind_ret = sum(ind_weight*stkcd_ret), stkcd_ret, symbol, capt), keyby = .(industry, date)
    ][, .(ind_ret, mkt_weight = capt/sum(capt), stkcd_ret, industry), keyby = date
    ][, .(ind_ret, mkt_ret = sum(mkt_weight*stkcd_ret), industry), keyby = date
    ][ind_ret > mkt_ret, unique(.SD)]
# Out:
#      date     ind_ret       mkt_ret      industry
# 1    20120104 -0.0084033878 -0.015816484 AERODEF
# 2    20120104 -0.0130576592 -0.015816484 AUTO
# 3    20120104 -0.0067372496 -0.015816484 BANKS
# 4    20120104 -0.0037138310 -0.015816484 ENERGY
# 5    20120104 -0.0113401442 -0.015816484 HOUSEDUR
# 6    20120104 -0.0099071718 -0.015816484 RDRLTRAN
# 7    20120104 -0.0092269648 -0.015816484 UTILITIE
# 8    20120105 -0.0120803353 -0.014367639 AIRLINE
# 9    20120105 -0.0085605288 -0.014367639 AUTO
# 10   20120105  0.0150350080 -0.014367639 BANKS
# 11   20120105 -0.0129426638 -0.014367639 BEV
# 12   20120105 -0.0003189487 -0.014367639 ENERGY
# 13   20120105 -0.0020143546 -0.014367639 RDRLTRAN
# 14   20120106  0.0107404786  0.006892555 BEV
# 15   20120106  0.0102928408  0.006892555 CHEM
# 16   20120106  0.0119679270  0.006892555 DVFININS
# 17   20120106  0.0089417318  0.006892555 ELECEQP
# 18   20120106  0.0123954387  0.006892555 ENERGY
# 19   20120106  0.0083655711  0.006892555 HDWRSEMI
# 20   20120106  0.0183139151  0.006892555 INDCONG
# 21   20120106  0.0160152895  0.006892555 MTLMIN
# 22   20120106  0.0100498275  0.006892555 TRDDIST
# 23   20120106  0.0083220305  0.006892555 UTILITIE
# 24   20120109  0.0382030567  0.031126760 AIRLINE
# 25   20120109  0.0407960743  0.031126760 AUTO
# 26   20120109  0.0383716539  0.031126760 BLDPROD
# 27   20120109  0.0477947842  0.031126760 CHEM
# 28   20120109  0.0321084997  0.031126760 CNSTENG
# 29   20120109  0.0336308907  0.031126760 COMSERV
# 30   20120109  0.0513309652  0.031126760 CONMAT
# ...  ...      ...           ...          ...
# 1820 20120627 -0.0003413623 -0.001815144 ENERGY
# 1821 20120627  0.0007534239 -0.001815144 FOODPROD
# 1822 20120627  0.0071924693 -0.001815144 HEALTH
# 1823 20120627  0.0015367229 -0.001815144 PERSPRD
# 1824 20120627 -0.0013372407 -0.001815144 REALEST
# 1825 20120627 -0.0016403348 -0.001815144 RETAIL
# 1826 20120627  0.0031123204 -0.001815144 SOFTWARE
# 1827 20120627  0.0006544063 -0.001815144 UTILITIE
# 1828 20120628 -0.0080202056 -0.009105539 AERODEF
# 1829 20120628 -0.0087637006 -0.009105539 AIRLINE
# 1830 20120628 -0.0049461781 -0.009105539 BANKS
# 1831 20120628 -0.0077382318 -0.009105539 BEV
# 1832 20120628 -0.0001602161 -0.009105539 DVFININS
# 1833 20120628 -0.0082788029 -0.009105539 ENERGY
# 1834 20120628  0.0034406867 -0.009105539 HEALTH
# 1835 20120628 -0.0070650053 -0.009105539 HOUSEDUR
# 1836 20120628 -0.0056206958 -0.009105539 PERSPRD
# 1837 20120628 -0.0049268965 -0.009105539 UTILITIE
# 1838 20120629  0.0133819384  0.013166202 AERODEF
# 1839 20120629  0.0187671632  0.013166202 AIRLINE
# 1840 20120629  0.0205435789  0.013166202 BEV
# 1841 20120629  0.0168189754  0.013166202 COMSERV
# 1842 20120629  0.0163861015  0.013166202 CONSSERV
# 1843 20120629  0.0352819506  0.013166202 DVFININS
# 1844 20120629  0.0132946094  0.013166202 HDWRSEMI
# 1845 20120629  0.0183053934  0.013166202 HEALTH
# 1846 20120629  0.0204364923  0.013166202 INDCONG
# 1847 20120629  0.0171325755  0.013166202 MEDIA
# 1848 20120629  0.0144461885  0.013166202 MTLMIN
# 1849 20120629  0.0163040092  0.013166202 SOFTWARE

# %% [markdown]
# #### *36. 每天每个行业对市场的超额收益率是多少？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, symbol, ind_weight = capt/sum(capt), capt), keyby = .(industry,date)
    ][, .(ind_ret = sum(ind_weight*stkcd_ret), stkcd_ret, symbol, capt), keyby = .(industry, date)
    ][, .(ind_ret, mkt_weight = capt/sum(capt), stkcd_ret, industry), keyby = date
    ][, .(ind_ret, mkt_ret = sum(mkt_weight*stkcd_ret), industry), keyby = date
    ][, unique(.SD)
    ][, .(alpha = coef(lm(ind_ret ~ mkt_ret))[1], beta = coef(lm(ind_ret ~ mkt_ret))[2], ind_ret, mkt_ret, industry, date)
    ][, .(abnr_ret = ind_ret - alpha - beta*mkt_ret, date), by = industry]
# Out:
#      industry abnr_ret      date
# 1    AERODEF   0.0098993621 20120104
# 2    AERODEF  -0.0087391716 20120105
# 3    AERODEF  -0.0282474476 20120106
# 4    AERODEF  -0.0062830802 20120109
# 5    AERODEF   0.0053427162 20120110
# 6    AERODEF   0.0033921876 20120111
# 7    AERODEF   0.0051834662 20120112
# 8    AERODEF  -0.0276084669 20120113
# 9    AERODEF  -0.0160809883 20120116
# 10   AERODEF   0.0035080100 20120117
# 11   AERODEF   0.0003116901 20120118
# 12   AERODEF  -0.0146797387 20120119
# 13   AERODEF  -0.0038367651 20120120
# 14   AERODEF   0.0163642334 20120130
# 15   AERODEF  -0.0014338757 20120131
# 16   AERODEF  -0.0043329017 20120201
# 17   AERODEF  -0.0061198737 20120202
# 18   AERODEF   0.0210484545 20120203
# 19   AERODEF  -0.0078022924 20120206
# 20   AERODEF   0.0278675821 20120207
# 21   AERODEF  -0.0062681024 20120208
# 22   AERODEF  -0.0029203585 20120209
# 23   AERODEF   0.0003290820 20120210
# 24   AERODEF   0.0133784567 20120213
# 25   AERODEF  -0.0006599407 20120214
# 26   AERODEF  -0.0012860649 20120215
# 27   AERODEF  -0.0007679714 20120216
# 28   AERODEF   0.0013723123 20120217
# 29   AERODEF   0.0098276831 20120220
# 30   AERODEF   0.0024366726 20120221
# ...  ...      ...           ...
# 3715 UTILITIE  0.0133447335 20120518
# 3716 UTILITIE -0.0051178842 20120521
# 3717 UTILITIE -0.0091109000 20120522
# 3718 UTILITIE  0.0008456875 20120523
# 3719 UTILITIE -0.0050900376 20120524
# 3720 UTILITIE  0.0019575692 20120525
# 3721 UTILITIE -0.0069252312 20120528
# 3722 UTILITIE -0.0048092568 20120529
# 3723 UTILITIE  0.0015919825 20120530
# 3724 UTILITIE  0.0042503340 20120531
# 3725 UTILITIE  0.0022515733 20120601
# 3726 UTILITIE  0.0119210706 20120604
# 3727 UTILITIE  0.0168381274 20120605
# 3728 UTILITIE  0.0026995190 20120606
# 3729 UTILITIE  0.0056047032 20120607
# 3730 UTILITIE  0.0079146446 20120608
# 3731 UTILITIE -0.0043474882 20120611
# 3732 UTILITIE  0.0025051896 20120612
# 3733 UTILITIE  0.0184629005 20120613
# 3734 UTILITIE  0.0077178697 20120614
# 3735 UTILITIE  0.0037937256 20120615
# 3736 UTILITIE -0.0017444923 20120618
# 3737 UTILITIE -0.0009126751 20120619
# 3738 UTILITIE -0.0052631125 20120620
# 3739 UTILITIE  0.0130087832 20120621
# 3740 UTILITIE  0.0192953654 20120625
# 3741 UTILITIE -0.0081706397 20120626
# 3742 UTILITIE  0.0026765246 20120627
# 3743 UTILITIE  0.0055724273 20120628
# 3744 UTILITIE -0.0127053575 20120629

# %% [markdown]
# #### *37. 每天每个行业对去除本行业后的市场超额收益是多少？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, symbol, ind_weight = capt/sum(capt), capt), keyby = .(industry,date)
    ][, .(ind_ret = sum(ind_weight*stkcd_ret), stkcd_ret, symbol, capt), keyby = .(industry, date)
    ][, .(ind_capt = sum(capt), ind_ret), keyby = .(industry, date)
    ][, unique(.SD)
    ][, .(ind_mkt_weight = ind_capt/(sum(ind_capt)-ind_capt), ind_ret, industry), keyby = date
    ][, .(mkt_ret = sum(ind_mkt_weight * ind_ret), ind_ret, industry), by = date
    ][, .(alpha = coef(lm(ind_ret ~ mkt_ret))[1], beta = coef(lm(ind_ret ~ mkt_ret))[2], ind_ret, mkt_ret, industry, date)
    ][, .(abnr_ret = ind_ret - alpha - beta*mkt_ret, date), by = industry]
# Out:
#      industry abnr_ret      date
# 1    AERODEF   0.0094213482 20120104
# 2    AERODEF  -0.0101032674 20120105
# 3    AERODEF  -0.0286978408 20120106
# 4    AERODEF  -0.0065539745 20120109
# 5    AERODEF   0.0057905729 20120110
# 6    AERODEF   0.0036557266 20120111
# 7    AERODEF   0.0050883770 20120112
# 8    AERODEF  -0.0286276061 20120113
# 9    AERODEF  -0.0164406859 20120116
# 10   AERODEF   0.0034710088 20120117
# 11   AERODEF   0.0005008448 20120118
# 12   AERODEF  -0.0148661696 20120119
# 13   AERODEF  -0.0037719964 20120120
# 14   AERODEF   0.0168892444 20120130
# 15   AERODEF  -0.0016973903 20120131
# 16   AERODEF  -0.0041785761 20120201
# 17   AERODEF  -0.0066021886 20120202
# 18   AERODEF   0.0212184496 20120203
# 19   AERODEF  -0.0075877569 20120206
# 20   AERODEF   0.0281435052 20120207
# 21   AERODEF  -0.0066781041 20120208
# 22   AERODEF  -0.0027341175 20120209
# 23   AERODEF   0.0006476541 20120210
# 24   AERODEF   0.0138440228 20120213
# 25   AERODEF  -0.0005814041 20120214
# 26   AERODEF  -0.0010385911 20120215
# 27   AERODEF  -0.0006250467 20120216
# 28   AERODEF   0.0012849208 20120217
# 29   AERODEF   0.0096320380 20120220
# 30   AERODEF   0.0025208245 20120221
# ...  ...      ...           ...
# 3715 UTILITIE  0.0134635310 20120518
# 3716 UTILITIE -0.0053006714 20120521
# 3717 UTILITIE -0.0089124822 20120522
# 3718 UTILITIE  0.0009852673 20120523
# 3719 UTILITIE -0.0052332309 20120524
# 3720 UTILITIE  0.0017429943 20120525
# 3721 UTILITIE -0.0067814240 20120528
# 3722 UTILITIE -0.0047124177 20120529
# 3723 UTILITIE  0.0017643930 20120530
# 3724 UTILITIE  0.0045782706 20120531
# 3725 UTILITIE  0.0022065428 20120601
# 3726 UTILITIE  0.0118892300 20120604
# 3727 UTILITIE  0.0166860877 20120605
# 3728 UTILITIE  0.0026276274 20120606
# 3729 UTILITIE  0.0056100324 20120607
# 3730 UTILITIE  0.0081377511 20120608
# 3731 UTILITIE -0.0042011474 20120611
# 3732 UTILITIE  0.0026370412 20120612
# 3733 UTILITIE  0.0188658718 20120613
# 3734 UTILITIE  0.0079050359 20120614
# 3735 UTILITIE  0.0033689685 20120615
# 3736 UTILITIE -0.0015654723 20120618
# 3737 UTILITIE -0.0010267218 20120619
# 3738 UTILITIE -0.0055216989 20120620
# 3739 UTILITIE  0.0131127224 20120621
# 3740 UTILITIE  0.0189027077 20120625
# 3741 UTILITIE -0.0081592958 20120626
# 3742 UTILITIE  0.0026302707 20120627
# 3743 UTILITIE  0.0054506414 20120628
# 3744 UTILITIE -0.0127666762 20120629

# %% [markdown]
# #### *38. 每天分别有多少股票是最近连续3个交易日上涨、下跌的？*

# %%
data[, .(stkcd_ret = close/pre_close - 1), keyby = .(symbol, date)
    ][, {
        l <- list()
        b1 <- stkcd_ret > 0
        b2 <- stkcd_ret < 0
        for (t in 4:.N) {
            l[[t]] <- as.list(c(r3day_up = mean(c(b1[t-1], b1[t-2], b1[t-3])), r3day_dn = mean(c(b2[t-1], b1[t-2], b1[t-3])), date = date[t]))
        }
        rbindlist(l)
    }    
    , keyby = .(symbol)
    ][!is.na(date), .(stkcd_amount = uniqueN(symbol)), keyby = .(date, tag = ifelse(r3day_up == 1, "r3day_up", ifelse(r3day_dn == 1, "r3day_dn", "others")))
    ][tag == "r3day_dn"|tag == "r3day_up"]
# Out:
#     date     tag      stkcd_amount
# 1   20120109 r3day_dn   17
# 2   20120109 r3day_up   16
# 3   20120110 r3day_dn    1
# 4   20120110 r3day_up   71
# 5   20120111 r3day_dn    6
# 6   20120111 r3day_up 1401
# 7   20120112 r3day_dn 1126
# 8   20120112 r3day_up  932
# 9   20120113 r3day_dn  641
# 10  20120113 r3day_up  272
# 11  20120116 r3day_dn  243
# 12  20120116 r3day_up   32
# 13  20120117 r3day_dn   49
# 14  20120117 r3day_up    4
# 15  20120118 r3day_up    7
# 16  20120119 r3day_dn   92
# 17  20120119 r3day_up    7
# 18  20120120 r3day_dn   53
# 19  20120120 r3day_up  145
# 20  20120130 r3day_dn   49
# 21  20120130 r3day_up  101
# 22  20120131 r3day_dn  981
# 23  20120131 r3day_up  419
# 24  20120201 r3day_dn  298
# 25  20120201 r3day_up  288
# 26  20120202 r3day_dn  219
# 27  20120202 r3day_up  112
# 28  20120203 r3day_dn   19
# 29  20120203 r3day_up  249
# 30  20120206 r3day_dn   56
# ... ...      ...      ...
# 198 20120608 r3day_dn 197
# 199 20120608 r3day_up  88
# 200 20120611 r3day_dn 120
# 201 20120611 r3day_up  96
# 202 20120612 r3day_dn  36
# 203 20120612 r3day_up 247
# 204 20120613 r3day_dn 534
# 205 20120613 r3day_up 226
# 206 20120614 r3day_dn  47
# 207 20120614 r3day_up 536
# 208 20120615 r3day_dn 460
# 209 20120615 r3day_up 136
# 210 20120618 r3day_dn 297
# 211 20120618 r3day_up 240
# 212 20120619 r3day_dn  76
# 213 20120619 r3day_up 166
# 214 20120620 r3day_dn 633
# 215 20120620 r3day_up 232
# 216 20120621 r3day_dn 280
# 217 20120621 r3day_up 196
# 218 20120625 r3day_dn 185
# 219 20120625 r3day_up  38
# 220 20120626 r3day_dn 116
# 221 20120626 r3day_up  26
# 222 20120627 r3day_dn  46
# 223 20120627 r3day_up  30
# 224 20120628 r3day_dn  48
# 225 20120628 r3day_up  48
# 226 20120629 r3day_dn 260
# 227 20120629 r3day_up  92

# %% [markdown]
# #### *39. 每天分别有多少股票是最近连续3个交易日收益率超过当天市场平均收益率？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, mkt_weight = capt/sum(capt), symbol), keyby = .(date)
    ][, .(mkt_ret = sum(stkcd_ret * mkt_weight), symbol, stkcd_ret), keyby = .(date)
    ][, .(r3day_ret = ifelse(stkcd_ret > mkt_ret, 1, 0)), keyby = .(symbol, date)
    ][, {
        l <- list()
        for (t in 4:.N) {
            l[[t]] <- as.list(c(r3day_ret = mean(c(r3day_ret[t-1], r3day_ret[t-2], r3day_ret[t-3])), date = date[t]))
        }
        rbindlist(l)
    }, keyby = symbol
    ][r3day_ret == 1 & !is.na(date), .(stkcd_amount = uniqueN(symbol)), keyby = date]
# Out:
#     date     stkcd_amount
# 1   20120109  81
# 2   20120110  95
# 3   20120111 785
# 4   20120112 905
# 5   20120113 392
# 6   20120116 153
# 7   20120117 145
# 8   20120118  50
# 9   20120119 169
# 10  20120120 238
# 11  20120130 116
# 12  20120131 312
# 13  20120201 354
# 14  20120202 340
# 15  20120203 130
# 16  20120206 337
# 17  20120207 417
# 18  20120208 320
# 19  20120209 154
# 20  20120210 117
# 21  20120213 351
# 22  20120214 523
# 23  20120215 399
# 24  20120216 506
# 25  20120217 366
# 26  20120220 199
# 27  20120221  97
# 28  20120222 117
# 29  20120223 310
# 30  20120224 300
# ... ...      ...
# 85  20120518 191
# 86  20120521 265
# 87  20120522 141
# 88  20120523 114
# 89  20120524 190
# 90  20120525 211
# 91  20120528 234
# 92  20120529 175
# 93  20120530 137
# 94  20120531 249
# 95  20120601 549
# 96  20120604 282
# 97  20120605 224
# 98  20120606 153
# 99  20120607 137
# 100 20120608 167
# 101 20120611 325
# 102 20120612 373
# 103 20120613 371
# 104 20120614 308
# 105 20120615 197
# 106 20120618 203
# 107 20120619 194
# 108 20120620 229
# 109 20120621 314
# 110 20120625 281
# 111 20120626 251
# 112 20120627 258
# 113 20120628 242
# 114 20120629 277

# %% [markdown]
# #### *40. 每天分别有多少股票是最新5个交易日中至少有4个交易日的收益率超过当天市场平均收益率？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, mkt_weight = capt/sum(capt), symbol), keyby = .(date)
    ][, .(mkt_ret = sum(stkcd_ret * mkt_weight), symbol, stkcd_ret), keyby = .(date)
    ][, .(r3day_ret = ifelse(stkcd_ret > mkt_ret, 1, 0)), keyby = .(symbol, date)
    ][, {
        l <- list()
        for (t in 6:.N) {
            l[[t]] <- as.list(c(r3day_ret = mean(c(r3day_ret[t-1], r3day_ret[t-2], r3day_ret[t-3], r3day_ret[t-4], r3day_ret[t-5])), date = date[t]))
        }
        rbindlist(l)
    }, keyby = symbol
    ][r3day_ret > 0.8 & !is.na(date), .(stkcd_amount = uniqueN(symbol)), keyby = date]
# Out:
#     date     stkcd_amount
# 1   20120111  14
# 2   20120112  22
# 3   20120113 184
# 4   20120116  48
# 5   20120117  18
# 6   20120118  13
# 7   20120119   8
# 8   20120120  12
# 9   20120130  35
# 10  20120131  36
# 11  20120201  18
# 12  20120202  64
# 13  20120203  51
# 14  20120206  51
# 15  20120207  48
# 16  20120208  70
# 17  20120209  47
# 18  20120210  53
# 19  20120213  27
# 20  20120214  35
# 21  20120215 112
# 22  20120216 159
# 23  20120217 129
# 24  20120220  80
# 25  20120221  30
# 26  20120222  29
# 27  20120223  31
# 28  20120224  20
# 29  20120227  36
# 30  20120228  28
# ... ...      ...
# 83  20120518  40
# 84  20120521  50
# 85  20120522  21
# 86  20120523  12
# 87  20120524  17
# 88  20120525  19
# 89  20120528  33
# 90  20120529  48
# 91  20120530  25
# 92  20120531  31
# 93  20120601  33
# 94  20120604  46
# 95  20120605  75
# 96  20120606  59
# 97  20120607  51
# 98  20120608  31
# 99  20120611  37
# 100 20120612  41
# 101 20120613  75
# 102 20120614  76
# 103 20120615  59
# 104 20120618  50
# 105 20120619  39
# 106 20120620  48
# 107 20120621  32
# 108 20120625  50
# 109 20120626  54
# 110 20120627 120
# 111 20120628 101
# 112 20120629 122

# %% [markdown]
# #### *41. 每个月中，个股月收益超过市场月收益1倍以上的股票有哪些？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, mkt_weight = capt/sum(capt), symbol), keyby = .(date)
    ][, .(mkt_ret = sum(mkt_weight * stkcd_ret), stkcd_ret, symbol, date_ym = str_sub(date, start = 1, end = 6)), keyby = .(date)
    ][, .(stkcd_m_ret = mean(stkcd_ret), date, mkt_ret), keyby = .(symbol, date_ym)
    ][, .(stkcd_m_ret, symbol, date, mkt_m_ret = mean(mkt_ret)), keyby = .(date_ym)
    ][stkcd_m_ret > 2*mkt_m_ret, .(symbol = unique(symbol)), keyby = .(date_ym)]
# Out:
#      date_ym symbol
# 1    201201  000009.SZ
# 2    201201  000012.SZ
# 3    201201  000017.SZ
# 4    201201  000018.SZ
# 5    201201  000030.SZ
# 6    201201  000034.SZ
# 7    201201  000039.SZ
# 8    201201  000040.SZ
# 9    201201  000043.SZ
# 10   201201  000059.SZ
# 11   201201  000060.SZ
# 12   201201  000100.SZ
# 13   201201  000157.SZ
# 14   201201  000159.SZ
# 15   201201  000408.SZ
# 16   201201  000416.SZ
# 17   201201  000418.SZ
# 18   201201  000425.SZ
# 19   201201  000426.SZ
# 20   201201  000502.SZ
# 21   201201  000504.SZ
# 22   201201  000505.SZ
# 23   201201  000506.SZ
# 24   201201  000510.SZ
# 25   201201  000519.SZ
# 26   201201  000528.SZ
# 27   201201  000531.SZ
# 28   201201  000537.SZ
# 29   201201  000550.SZ
# 30   201201  000552.SZ
# ...  ...     ...
# 5980 201206  601677.SH
# 5981 201206  601688.SH
# 5982 201206  601700.SH
# 5983 201206  601718.SH
# 5984 201206  601766.SH
# 5985 201206  601777.SH
# 5986 201206  601788.SH
# 5987 201206  601798.SH
# 5988 201206  601799.SH
# 5989 201206  601808.SH
# 5990 201206  601818.SH
# 5991 201206  601857.SH
# 5992 201206  601872.SH
# 5993 201206  601877.SH
# 5994 201206  601880.SH
# 5995 201206  601886.SH
# 5996 201206  601888.SH
# 5997 201206  601899.SH
# 5998 201206  601901.SH
# 5999 201206  601919.SH
# 6000 201206  601928.SH
# 6001 201206  601929.SH
# 6002 201206  601933.SH
# 6003 201206  601939.SH
# 6004 201206  601988.SH
# 6005 201206  601991.SH
# 6006 201206  601996.SH
# 6007 201206  601998.SH
# 6008 201206  603000.SH
# 6009 201206  603001.SH

# %% [markdown]
# #### *42. 每个月中，个股月收益超过行业月收益1倍以上的股票有哪些？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, ind_weight = capt/sum(capt), symbol), keyby = .(industry, date)
    ][, .(ind_ret = sum(ind_weight * stkcd_ret), stkcd_ret, symbol, date_ym = str_sub(date, start = 1, end = 6)), keyby = .(industry, date)
    ][, .(stkcd_m_ret = mean(stkcd_ret), date, ind_ret), keyby = .(symbol, date_ym)
    ][, .(stkcd_m_ret, symbol, date, ind_m_ret = mean(ind_ret)), keyby = .(date_ym)
    ][stkcd_m_ret > 2*ind_m_ret, .(symbol = unique(symbol)), keyby = .(date_ym)]
# Out:
#      date_ym symbol
# 1    201201  000001.SZ
# 2    201201  000006.SZ
# 3    201201  000007.SZ
# 4    201201  000009.SZ
# 5    201201  000012.SZ
# 6    201201  000017.SZ
# 7    201201  000018.SZ
# 8    201201  000020.SZ
# 9    201201  000021.SZ
# 10   201201  000022.SZ
# 11   201201  000029.SZ
# 12   201201  000030.SZ
# 13   201201  000033.SZ
# 14   201201  000034.SZ
# 15   201201  000036.SZ
# 16   201201  000037.SZ
# 17   201201  000039.SZ
# 18   201201  000040.SZ
# 19   201201  000042.SZ
# 20   201201  000043.SZ
# 21   201201  000045.SZ
# 22   201201  000059.SZ
# 23   201201  000060.SZ
# 24   201201  000069.SZ
# 25   201201  000089.SZ
# 26   201201  000096.SZ
# 27   201201  000100.SZ
# 28   201201  000155.SZ
# 29   201201  000157.SZ
# 30   201201  000159.SZ
# ...  ...     ...
# 5792 201206  601777.SH
# 5793 201206  601788.SH
# 5794 201206  601798.SH
# 5795 201206  601799.SH
# 5796 201206  601808.SH
# 5797 201206  601818.SH
# 5798 201206  601857.SH
# 5799 201206  601872.SH
# 5800 201206  601877.SH
# 5801 201206  601880.SH
# 5802 201206  601886.SH
# 5803 201206  601888.SH
# 5804 201206  601890.SH
# 5805 201206  601899.SH
# 5806 201206  601901.SH
# 5807 201206  601919.SH
# 5808 201206  601928.SH
# 5809 201206  601929.SH
# 5810 201206  601933.SH
# 5811 201206  601939.SH
# 5812 201206  601958.SH
# 5813 201206  601988.SH
# 5814 201206  601991.SH
# 5815 201206  601996.SH
# 5816 201206  601998.SH
# 5817 201206  603000.SH
# 5818 201206  603001.SH
# 5819 201206  603002.SH
# 5820 201206  603123.SH
# 5821 201206  603366.SH

# %% [markdown]
# #### *43. 每个股票的收益率对市场收益率的相关系数最高的10个股票是哪些？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, mkt_weight = capt/sum(capt), symbol), keyby = .(date)
    ][, .(stkcd_ret, mkt_ret = sum(mkt_weight * stkcd_ret), symbol), keyby = .(date)
    ][, .(cor_coef = cor(stkcd_ret, mkt_ret)), keyby = symbol
    ][order(-cor_coef), .SD[1:10]]
# Out:
# Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"Warning message in cor(stkcd_ret, mkt_ret):
# "the standard deviation is zero"
#    symbol    cor_coef
# 1  300331.SZ 1.0000000
# 2  600508.SH 0.9279554
# 3  601101.SH 0.9097758
# 4  000685.SZ 0.8979148
# 5  601666.SH 0.8939529
# 6  002082.SZ 0.8932496
# 7  002212.SZ 0.8919200
# 8  601001.SH 0.8918933
# 9  000089.SZ 0.8914474
# 10 601168.SH 0.8888058

# %% [markdown]
# #### *44. 每个行业日收益率的历史波动率是多少？（用日收益率计算标准差）*

# %%
data[, .(stkcd_ret = close/pre_close - 1, ind_weight = capt/sum(capt), symbol), keyby = .(industry, date)
    ][, .(ind_ret = sum(stkcd_ret * ind_weight)), keyby = .(industry, date)
    ][, .(ind_vol = sd(ind_ret)), keyby = .(industry)]
# Out:
#    industry ind_vol
# 1  AERODEF  0.017499519
# 2  AIRLINE  0.017127041
# 3  AUTO     0.015096513
# 4  BANKS    0.008105859
# 5  BEV      0.016407569
# 6  BLDPROD  0.016608454
# 7  CHEM     0.017265568
# 8  CNSTENG  0.015309948
# 9  COMSERV  0.017256929
# 10 CONMAT   0.021499559
# 11 CONSSERV 0.014880445
# 12 DVFININS 0.018947275
# 13 ELECEQP  0.016272932
# 14 ENERGY   0.010657638
# 15 FOODPROD 0.015784999
# 16 HDWRSEMI 0.015933517
# 17 HEALTH   0.015500388
# 18 HOUSEDUR 0.015174520
# 19 INDCONG  0.019694102
# 20 LEISLUX  0.015416494
# 21 MACH     0.016835870
# 22 MARINE   0.018242449
# 23 MATERIAL 0.015679706
# 24 MEDIA    0.018031674
# 25 MTLMIN   0.017471696
# 26 PERSPRD  0.015276960
# 27 RDRLTRAN 0.009676438
# 28 REALEST  0.017360888
# 29 RETAIL   0.015780145
# 30 SOFTWARE 0.018210055
# 31 TRDDIST  0.017189914
# 32 UTILITIE 0.011773004

# %% [markdown]
# #### *45. 各个行业的日收益率的相关系数矩阵如何？哪两个行业相关性最高、最低？*

# %%
cor.coef <- data[, .(stkcd_ret = close/pre_close - 1, ind_weight = capt/sum(capt), symbol, capt), keyby = .(industry, date)
    ][, .(ind_ret = sum(stkcd_ret * ind_weight)), keyby = .(industry, date)
    ][,  dcast(.SD, date ~ industry, value.var = "ind_ret")
    ][, cor(.SD[, -1])]
which(max(cor.coef[cor.coef != 1]) == cor.coef, arr.ind = TRUE)
which(min(cor.coef) == cor.coef, arr.ind = TRUE)
rm(cor.coef)
# Out:
#          row col
# HDWRSEMI 16  13
# ELECEQP  13  16
#       row col
# BEV   5   4
# BANKS 4   5

# %% [markdown]
# #### *46. 各个行业的收益率对市场收益率的相关系数由高到低排列如何？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, symbol, ind_weight = capt/sum(capt), capt), keyby = .(industry,date)
    ][, .(ind_ret = sum(ind_weight*stkcd_ret), stkcd_ret, symbol, capt), keyby = .(industry, date)
    ][, .(ind_ret, mkt_weight = capt/sum(capt), stkcd_ret, industry), keyby = date
    ][, .(ind_ret, mkt_ret = sum(mkt_weight*stkcd_ret), industry), keyby = date
    ][, unique(.SD)
    ][, .(cor_coef = cor(ind_ret, mkt_ret)), keyby = .(industry)
    ][order(-cor_coef)]
# Out:
#    industry cor_coef
# 1  TRDDIST  0.9519013
# 2  MACH     0.9511527
# 3  CHEM     0.9455305
# 4  ELECEQP  0.9451663
# 5  CNSTENG  0.9446049
# 6  LEISLUX  0.9349492
# 7  HDWRSEMI 0.9285804
# 8  ENERGY   0.9156957
# 9  AUTO     0.9156441
# 10 RETAIL   0.9143200
# 11 MTLMIN   0.9135430
# 12 RDRLTRAN 0.9128735
# 13 CONSSERV 0.9110748
# 14 FOODPROD 0.8960934
# 15 PERSPRD  0.8906650
# 16 DVFININS 0.8863372
# 17 BLDPROD  0.8859437
# 18 CONMAT   0.8818781
# 19 UTILITIE 0.8782033
# 20 HOUSEDUR 0.8779418
# 21 COMSERV  0.8776912
# 22 INDCONG  0.8773895
# 23 AIRLINE  0.8719829
# 24 MEDIA    0.8685653
# 25 SOFTWARE 0.8662672
# 26 MARINE   0.8593283
# 27 MATERIAL 0.8568285
# 28 REALEST  0.8480311
# 29 HEALTH   0.8270723
# 30 AERODEF  0.7937509
# 31 BANKS    0.7389285
# 32 BEV      0.6570517

# %% [markdown]
# #### *47. 每个月总成交额比上个月下降幅度最大的行业是哪个？*

# %%
data[, .(date_ym = str_sub(date, start = 1, end = 6), amount), keyby = .(industry, date)
    ][, .(ind_m_amount = sum(amount)), keyby = .(industry, date_ym)
    ][, .(dn_m_range = {
        a <- vector()
        for (t in 2:.N) {
            a[t] <- ind_m_amount[t] - ind_m_amount[t-1]
        }
        a 
    }, date_ym = date_ym), keyby = industry
    ][!is.na(dn_m_range), .SD[min(dn_m_range) == dn_m_range & dn_m_range < 0], keyby = date_ym]
# Out:
#   date_ym industry dn_m_range
# 1 201203  CONMAT    -21752549725
# 2 201204  MTLMIN   -165775634730
# 3 201205  REALEST    -4528375663
# 4 201206  MTLMIN   -123271994315

# %% [markdown]
# #### *48. 数据当中各个股票的最大回撤幅度是多少？（最大回撤是从一个高点到低点的降幅的最大值）*

# %%
data[, .(max_rtrt = max(high) - min(low)), keyby = symbol]
# Out:
#      symbol    max_rtrt
# 1    000001.SZ  3.33
# 2    000002.SZ  2.43
# 3    000004.SZ  2.93
# 4    000005.SZ  1.74
# 5    000006.SZ  3.00
# 6    000007.SZ 10.72
# 7    000008.SZ  5.98
# 8    000009.SZ  5.32
# 9    000010.SZ  4.95
# 10   000011.SZ  4.26
# 11   000012.SZ  3.59
# 12   000014.SZ  6.09
# 13   000016.SZ  1.37
# 14   000017.SZ  1.13
# 15   000018.SZ  3.16
# 16   000019.SZ  5.02
# 17   000020.SZ  3.88
# 18   000021.SZ  1.78
# 19   000022.SZ  2.34
# 20   000023.SZ  3.39
# 21   000024.SZ  9.40
# 22   000025.SZ  3.55
# 23   000026.SZ  3.57
# 24   000027.SZ  1.11
# 25   000028.SZ 12.48
# 26   000029.SZ  1.66
# 27   000030.SZ  8.43
# 28   000031.SZ  1.61
# 29   000032.SZ  2.67
# 30   000033.SZ  2.37
# ...  ...       ...
# 2396 601880.SH  0.97
# 2397 601886.SH  6.58
# 2398 601888.SH  6.44
# 2399 601890.SH  3.51
# 2400 601898.SH  2.72
# 2401 601899.SH  1.13
# 2402 601901.SH  1.84
# 2403 601908.SH 20.99
# 2404 601918.SH  4.95
# 2405 601919.SH  1.76
# 2406 601928.SH  2.78
# 2407 601929.SH  6.65
# 2408 601933.SH  6.69
# 2409 601939.SH  0.79
# 2410 601958.SH  5.47
# 2411 601965.SH  1.06
# 2412 601988.SH  0.31
# 2413 601989.SH  2.31
# 2414 601991.SH  1.10
# 2415 601992.SH  4.01
# 2416 601996.SH  7.50
# 2417 601998.SH  0.81
# 2418 601999.SH  2.86
# 2419 603000.SH 17.03
# 2420 603001.SH  5.14
# 2421 603002.SH  2.27
# 2422 603123.SH  4.53
# 2423 603128.SH  1.78
# 2424 603333.SH  2.99
# 2425 603366.SH  3.94

# %% [markdown]
# #### *49. 每只股票的胜率是多少？（胜率是每天收益率为正数的概率）*

# %%
data[, .(stkcd_ret = close/pre_close - 1), keyby = .(symbol, date)
    ][, .(gain_ratio = sum(stkcd_ret > 0)/.N), keyby = symbol]
# Out:
#      symbol    gain_ratio
# 1    000001.SZ 0.4188034
# 2    000002.SZ 0.4700855
# 3    000004.SZ 0.5128205
# 4    000005.SZ 0.1538462
# 5    000006.SZ 0.5128205
# 6    000007.SZ 0.5555556
# 7    000008.SZ 0.4444444
# 8    000009.SZ 0.4957265
# 9    000010.SZ 0.3076923
# 10   000011.SZ 0.5299145
# 11   000012.SZ 0.4786325
# 12   000014.SZ 0.5555556
# 13   000016.SZ 0.4957265
# 14   000017.SZ 0.5128205
# 15   000018.SZ 0.5299145
# 16   000019.SZ 0.4102564
# 17   000020.SZ 0.5042735
# 18   000021.SZ 0.4786325
# 19   000022.SZ 0.4786325
# 20   000023.SZ 0.5555556
# 21   000024.SZ 0.5982906
# 22   000025.SZ 0.4871795
# 23   000026.SZ 0.4700855
# 24   000027.SZ 0.4700855
# 25   000028.SZ 0.5128205
# 26   000029.SZ 0.4529915
# 27   000030.SZ 0.4957265
# 28   000031.SZ 0.4957265
# 29   000032.SZ 0.4871795
# 30   000033.SZ 0.5470085
# ...  ...       ...
# 2396 601880.SH 0.4273504
# 2397 601886.SH 0.5128205
# 2398 601888.SH 0.5213675
# 2399 601890.SH 0.5299145
# 2400 601898.SH 0.3931624
# 2401 601899.SH 0.4273504
# 2402 601901.SH 0.4700855
# 2403 601908.SH 0.4444444
# 2404 601918.SH 0.4871795
# 2405 601919.SH 0.4188034
# 2406 601928.SH 0.4615385
# 2407 601929.SH 0.4651163
# 2408 601933.SH 0.4700855
# 2409 601939.SH 0.3846154
# 2410 601958.SH 0.4871795
# 2411 601965.SH 0.2857143
# 2412 601988.SH 0.3846154
# 2413 601989.SH 0.4529915
# 2414 601991.SH 0.4529915
# 2415 601992.SH 0.4700855
# 2416 601996.SH 0.5213675
# 2417 601998.SH 0.4358974
# 2418 601999.SH 0.4188034
# 2419 603000.SH 0.5348837
# 2420 603001.SH 0.5681818
# 2421 603002.SH 0.4333333
# 2422 603123.SH 0.3170732
# 2423 603128.SH 0.4782609
# 2424 603333.SH 0.3589744
# 2425 603366.SH 0.3793103

# %% [markdown]
# #### *50. 每只股票的盈亏比是多少？（盈亏比是正收益之和与负收益之和的比值的绝对值）*

# %%
data[, .(stkcd_ret = close/pre_close - 1), keyby = .(symbol, date)
    ][, .(stkcd_ret_pn = sum(stkcd_ret)), keyby = .(symbol, tag = ifelse(stkcd_ret > 0, "gain", "loss"))
    ][, .(gl_ratio = abs(stkcd_ret_pn[1]/stkcd_ret_pn[.N])), keyby = symbol]
# Out:
#      symbol    gl_ratio
# 1    000001.SZ 0.9718614
# 2    000002.SZ 1.2796856
# 3    000004.SZ 1.0828690
# 4    000005.SZ 0.5532427
# 5    000006.SZ 1.3719934
# 6    000007.SZ 1.8032631
# 7    000008.SZ 1.7014617
# 8    000009.SZ 0.9844944
# 9    000010.SZ 0.9652698
# 10   000011.SZ 1.1896667
# 11   000012.SZ 1.0477184
# 12   000014.SZ 1.5628405
# 13   000016.SZ 1.2088326
# 14   000017.SZ 1.1701765
# 15   000018.SZ 1.2839956
# 16   000019.SZ 1.1488428
# 17   000020.SZ 1.2956894
# 18   000021.SZ 1.1025433
# 19   000022.SZ 1.2340874
# 20   000023.SZ 1.1644178
# 21   000024.SZ 1.4214806
# 22   000025.SZ 1.1738517
# 23   000026.SZ 0.8664886
# 24   000027.SZ 1.1498476
# 25   000028.SZ 1.3477019
# 26   000029.SZ 1.1719727
# 27   000030.SZ 1.1181456
# 28   000031.SZ 1.2294070
# 29   000032.SZ 1.0589772
# 30   000033.SZ 1.3013300
# ...  ...       ...
# 2396 601880.SH 1.2316080
# 2397 601886.SH 1.2941390
# 2398 601888.SH 1.1231492
# 2399 601890.SH 0.9965271
# 2400 601898.SH 0.8614602
# 2401 601899.SH 1.0480211
# 2402 601901.SH 1.2320315
# 2403 601908.SH 0.8210967
# 2404 601918.SH 1.1246620
# 2405 601919.SH 1.0198484
# 2406 601928.SH 1.0713971
# 2407 601929.SH 1.4277633
# 2408 601933.SH 0.9216075
# 2409 601939.SH 0.9500732
# 2410 601958.SH 1.1585733
# 2411 601965.SH 0.1632617
# 2412 601988.SH 1.0683442
# 2413 601989.SH 1.0608064
# 2414 601991.SH 1.1486880
# 2415 601992.SH 0.8561130
# 2416 601996.SH 1.3751591
# 2417 601998.SH 0.9993577
# 2418 601999.SH 0.9471160
# 2419 603000.SH 3.0010534
# 2420 603001.SH 1.2158127
# 2421 603002.SH 3.3275208
# 2422 603123.SH 1.4154428
# 2423 603128.SH 1.2664079
# 2424 603333.SH 1.0208677
# 2425 603366.SH 0.7167108

# %% [markdown]
# #### *51. 市场的胜率是多少？（市场收益率为正的概率）*

# %%
data[, .(stkcd_ret = close/pre_close - 1, mkt_weight = capt/sum(capt)), keyby = date
    ][, .(mkt_ret = sum(stkcd_ret * mkt_weight)), keyby = date
    ][, .(gain_ratio = sum(mkt_ret > 0)/.N)]
# Out:
#   gain_ratio
# 1 0.4871795

# %% [markdown]
# #### *52. 市场的盈亏比是多少？（市场中每个股票的市值加权正收益和市值加权负收益之比）*

# %%
data[, .(stkcd_ret = close/pre_close - 1, mkt_weight = capt/sum(capt)), keyby = date
    ][, .(mkt_ret = sum(stkcd_ret * mkt_weight)), keyby = date
    ][, .(mkt_ret_pn = sum(mkt_ret)), keyby = .(tag = ifelse(mkt_ret > 0, "gain", "loss"))
    ][, .(gl_ratio = abs(mkt_ret_pn[1]/mkt_ret_pn[.N]))]
# Out:
#   gl_ratio
# 1 1.147373

# %% [markdown]
# #### *53. 每个行业的胜率是多少？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, ind_weight = capt/sum(capt)), keyby = .(industry, date)
    ][, .(ind_ret = sum(stkcd_ret * ind_weight)), keyby = .(industry, date)
    ][, .(gain_ratio = sum(ind_ret > 0)/.N), keyby = industry]
# Out:
#    industry gain_ratio
# 1  AERODEF  0.5213675
# 2  AIRLINE  0.4786325
# 3  AUTO     0.4700855
# 4  BANKS    0.4615385
# 5  BEV      0.5470085
# 6  BLDPROD  0.5384615
# 7  CHEM     0.4957265
# 8  CNSTENG  0.5470085
# 9  COMSERV  0.5213675
# 10 CONMAT   0.5299145
# 11 CONSSERV 0.5128205
# 12 DVFININS 0.4700855
# 13 ELECEQP  0.4957265
# 14 ENERGY   0.4529915
# 15 FOODPROD 0.5213675
# 16 HDWRSEMI 0.4957265
# 17 HEALTH   0.5555556
# 18 HOUSEDUR 0.4786325
# 19 INDCONG  0.5470085
# 20 LEISLUX  0.4786325
# 21 MACH     0.5128205
# 22 MARINE   0.5213675
# 23 MATERIAL 0.4957265
# 24 MEDIA    0.5213675
# 25 MTLMIN   0.4700855
# 26 PERSPRD  0.5555556
# 27 RDRLTRAN 0.4786325
# 28 REALEST  0.5299145
# 29 RETAIL   0.5213675
# 30 SOFTWARE 0.5555556
# 31 TRDDIST  0.5470085
# 32 UTILITIE 0.5470085

# %% [markdown]
# #### *54. 每个行业的盈亏比是多少？（行业盈亏比是行业内每个股票的市值加权的正收益率和市值加权的负收益率之比）*

# %%
data[, .(stkcd_ret = close/pre_close - 1, ind_weight = capt/sum(capt)), keyby = .(industry, date)
    ][, .(ind_ret = sum(stkcd_ret * ind_weight)), keyby = .(industry, date)
    ][, .(ind_ret_pn = sum(ind_ret)), keyby = .(industry, tag = ifelse(ind_ret > 0, "gain", "loss"))
    ][, .(gl_ratio = abs(ind_ret_pn[1]/ind_ret_pn[.N])), keyby = industry]
# Out:
#    industry gl_ratio
# 1  AERODEF  0.9973617
# 2  AIRLINE  1.0715381
# 3  AUTO     1.1206090
# 4  BANKS    1.0158729
# 5  BEV      1.2812672
# 6  BLDPROD  1.2698791
# 7  CHEM     1.1149151
# 8  CNSTENG  1.2415376
# 9  COMSERV  1.1990343
# 10 CONMAT   1.0274717
# 11 CONSSERV 1.2688934
# 12 DVFININS 1.2936453
# 13 ELECEQP  0.9654093
# 14 ENERGY   0.9241949
# 15 FOODPROD 1.0948452
# 16 HDWRSEMI 1.0523145
# 17 HEALTH   1.2690412
# 18 HOUSEDUR 1.2357025
# 19 INDCONG  1.3100780
# 20 LEISLUX  1.1090097
# 21 MACH     1.1233997
# 22 MARINE   1.0145313
# 23 MATERIAL 1.1967891
# 24 MEDIA    1.0512003
# 25 MTLMIN   1.1468914
# 26 PERSPRD  1.1997349
# 27 RDRLTRAN 1.0705692
# 28 REALEST  1.3662439
# 29 RETAIL   1.1038942
# 30 SOFTWARE 1.0718943
# 31 TRDDIST  1.2019826
# 32 UTILITIE 1.2665183

# %% [markdown]
# #### *55. 是否存在股票的月成交额超过所在行业当月中某天一天总成交额的情况？*

# %%
data[, .(date_ym = str_sub(date, start = 1, end = 6), amount, industry), keyby = .(symbol, date)
    ][, .(stkcd_m_amount = sum(amount), amount, industry, date), keyby = .(date_ym, symbol)
    ][, .(stkcd_m_amount, ind_d_amount = sum(amount), date_ym, symbol), keyby = .(industry, date)
    ][stkcd_m_amount > ind_d_amount]
# Out:
#       industry date     stkcd_m_amount ind_d_amount date_ym symbol
# 1     AERODEF  20120104 1460111191     493331236    201201  000768.SZ
# 2     AERODEF  20120104  976641005     493331236    201201  002025.SZ
# 3     AERODEF  20120104 1125117546     493331236    201201  600118.SH
# 4     AERODEF  20120104 1522650678     493331236    201201  600316.SH
# 5     AERODEF  20120104  675067956     493331236    201201  600879.SH
# 6     AERODEF  20120104 1231862218     493331236    201201  600893.SH
# 7     AERODEF  20120105 1460111191     548805394    201201  000768.SZ
# 8     AERODEF  20120105  976641005     548805394    201201  002025.SZ
# 9     AERODEF  20120105 1125117546     548805394    201201  600118.SH
# 10    AERODEF  20120105 1522650678     548805394    201201  600316.SH
# 11    AERODEF  20120105  675067956     548805394    201201  600879.SH
# 12    AERODEF  20120105 1231862218     548805394    201201  600893.SH
# 13    AERODEF  20120106 1460111191     627367060    201201  000768.SZ
# 14    AERODEF  20120106  976641005     627367060    201201  002025.SZ
# 15    AERODEF  20120106 1125117546     627367060    201201  600118.SH
# 16    AERODEF  20120106 1522650678     627367060    201201  600316.SH
# 17    AERODEF  20120106  675067956     627367060    201201  600879.SH
# 18    AERODEF  20120106 1231862218     627367060    201201  600893.SH
# 19    AERODEF  20120109 1460111191     505922745    201201  000768.SZ
# 20    AERODEF  20120109  976641005     505922745    201201  002025.SZ
            len1 <- length(symbol_list[[i]])
            len2 <- length(symbol_list[[i-1]])
            l[[i]] <- list(export = len2-intec, import = len1-intec)
        }
        rbindlist(l)
    }, keyby = industry]
# Out:
#      industry export import
# 1    AERODEF  0      0
# 2    AERODEF  0      0
# 3    AERODEF  0      0
# 4    AERODEF  0      0
# 5    AERODEF  0      0
# 6    AERODEF  0      0
# 7    AERODEF  0      0
# 8    AERODEF  0      0
# 9    AERODEF  0      0
# 10   AERODEF  0      0
# 11   AERODEF  0      0
# 12   AERODEF  0      0
# 13   AERODEF  0      0
# 14   AERODEF  0      0
# 15   AERODEF  0      0
# 16   AERODEF  0      0
# 17   AERODEF  0      0
# 18   AERODEF  0      0
# 19   AERODEF  0      0
# 20   AERODEF  0      0
# 21   AERODEF  0      0
# 22   AERODEF  0      0
# 23   AERODEF  0      0
# 24   AERODEF  0      0
# 25   AERODEF  0      0
# 26   AERODEF  0      0
# 27   AERODEF  0      0
# 28   AERODEF  0      0
# 29   AERODEF  0      0
# 30   AERODEF  0      0
# ...  ...      ...    ...
# 3683 UTILITIE 0      0
# 3684 UTILITIE 0      0
# 3685 UTILITIE 0      0
# 3686 UTILITIE 0      0
# 3687 UTILITIE 0      0
# 3688 UTILITIE 0      0
# 3689 UTILITIE 0      0
# 3690 UTILITIE 0      0
# 3691 UTILITIE 0      0
# 3692 UTILITIE 0      0
# 3693 UTILITIE 0      1
# 3694 UTILITIE 0      0
# 3695 UTILITIE 0      0
# 3696 UTILITIE 0      0
# 3697 UTILITIE 0      0
# 3698 UTILITIE 0      0
# 3699 UTILITIE 0      0
# 3700 UTILITIE 0      0
# 3701 UTILITIE 0      0
# 3702 UTILITIE 0      0
# 3703 UTILITIE 0      0
# 3704 UTILITIE 0      0
# 3705 UTILITIE 0      0
# 3706 UTILITIE 0      0
# 3707 UTILITIE 0      0
# 3708 UTILITIE 0      0
# 3709 UTILITIE 0      0
# 3710 UTILITIE 0      0
# 3711 UTILITIE 0      0
# 3712 UTILITIE 0      0

# %% [markdown]
# #### *57. 每天每个行业内股票收益率的标准差是多少？*

# %%
data[, .(stkcd_ret = close/pre_close - 1), keyby = .(symbol, industry, date)
    ][, .(ret_sd = sd(stkcd_ret)), keyby = .(industry, date)]
# Out:
#      industry date     ret_sd
# 1    AERODEF  20120104 0.028368795
# 2    AERODEF  20120105 0.029020206
# 3    AERODEF  20120106 0.031931409
# 4    AERODEF  20120109 0.013774933
# 5    AERODEF  20120110 0.014172288
# 6    AERODEF  20120111 0.012716938
# 7    AERODEF  20120112 0.015646738
# 8    AERODEF  20120113 0.015327578
# 9    AERODEF  20120116 0.013199788
# 10   AERODEF  20120117 0.012681424
# 11   AERODEF  20120118 0.011610977
# 12   AERODEF  20120119 0.016473472
# 13   AERODEF  20120120 0.010727133
# 14   AERODEF  20120130 0.013152774
# 15   AERODEF  20120131 0.012325435
# 16   AERODEF  20120201 0.010929918
# 17   AERODEF  20120202 0.003688354
# 18   AERODEF  20120203 0.018103676
# 19   AERODEF  20120206 0.008747776
# 20   AERODEF  20120207 0.030650728
# 21   AERODEF  20120208 0.011432460
# 22   AERODEF  20120209 0.008638588
# 23   AERODEF  20120210 0.005203473
# 24   AERODEF  20120213 0.008511979
# 25   AERODEF  20120214 0.010059053
# 26   AERODEF  20120215 0.009175957
# 27   AERODEF  20120216 0.030506808
# 28   AERODEF  20120217 0.007650917
# 29   AERODEF  20120220 0.019091874
# 30   AERODEF  20120221 0.011055999
# ...  ...      ...      ...
# 3715 UTILITIE 20120518 0.018525083
# 3716 UTILITIE 20120521 0.021626538
# 3717 UTILITIE 20120522 0.008861422
# 3718 UTILITIE 20120523 0.016696596
# 3719 UTILITIE 20120524 0.013798881
# 3720 UTILITIE 20120525 0.019858764
# 3721 UTILITIE 20120528 0.013782185
# 3722 UTILITIE 20120529 0.015505377
# 3723 UTILITIE 20120530 0.019102570
# 3724 UTILITIE 20120531 0.019486330
# 3725 UTILITIE 20120601 0.014012860
# 3726 UTILITIE 20120604 0.026159634
# 3727 UTILITIE 20120605 0.020362464
# 3728 UTILITIE 20120606 0.016105496
# 3729 UTILITIE 20120607 0.023025395
# 3730 UTILITIE 20120608 0.024049877
# 3731 UTILITIE 20120611 0.021952840
# 3732 UTILITIE 20120612 0.013013043
# 3733 UTILITIE 20120613 0.020462591
# 3734 UTILITIE 20120614 0.020413201
# 3735 UTILITIE 20120615 0.026520570
# 3736 UTILITIE 20120618 0.018214183
# 3737 UTILITIE 20120619 0.015733283
# 3738 UTILITIE 20120620 0.017425427
# 3739 UTILITIE 20120621 0.018197908
# 3740 UTILITIE 20120625 0.019760241
# 3741 UTILITIE 20120626 0.018382344
# 3742 UTILITIE 20120627 0.014828996
# 3743 UTILITIE 20120628 0.021611569
# 3744 UTILITIE 20120629 0.012881628

# %% [markdown]
# #### *58. 每天每个行业内股票收益率的标准差的相关性如何？*

# %%
data[, .(stkcd_ret = close/pre_close - 1), keyby = .(symbol, industry, date)
    ][, .(ret_sd = sd(stkcd_ret)), keyby = .(industry, date)
    ][, dcast(.SD, date ~ industry, value.var = "ret_sd")
    ][, cor(.SD[, -1])]
# Out:
#          AERODEF     AIRLINE      AUTO       BANKS        BEV
# AERODEF   1.00000000  0.115230313 0.33195634  0.080215236 0.02497865
# AIRLINE   0.11523031  1.000000000 0.22235548  0.024461977 0.02250268
# AUTO      0.33195634  0.222355484 1.00000000  0.072839622 0.26374233
# BANKS     0.08021524  0.024461977 0.07283962  1.000000000 0.06073737
# BEV       0.02497865  0.022502678 0.26374233  0.060737370 1.00000000
# BLDPROD   0.23517920  0.119219798 0.52067326  0.160753394 0.35228913
# CHEM      0.18861102  0.167029633 0.36954048  0.157010691 0.11448273
# CNSTENG   0.21682816  0.301270197 0.32496927 -0.010450569 0.21168533
# COMSERV   0.25731553  0.125236551 0.57458415  0.017723962 0.13948967
# CONMAT    0.39057378  0.170596020 0.28974566  0.203366025 0.11835709
# CONSSERV  0.11297086  0.087637623 0.31919346  0.111789408 0.17656034
# DVFININS  0.01369501  0.192232189 0.21495658  0.053597753 0.13048470
# ELECEQP   0.30196572  0.176011583 0.57693184  0.086505952 0.32525817
*

# %%
data[, .(stkcd_ret = close/pre_close - 1, weight = capt/sum(capt), symbol, amount), keyby = date
    ][, .(mkt_ret = sum(weight*stkcd_ret), stkcd_ret, symbol, amount), keyby = date
    ][, .(alpha = coef(lm(stkcd_ret ~ mkt_ret))[1], beta = coef(lm(stkcd_ret ~ mkt_ret))[2], mkt_ret, stkcd_ret, symbol, date, amount)
    ][, .(abnr_ret = stkcd_ret - alpha - beta * mkt_ret, amount), keyby = .(date, symbol)
    ][, .(abnr_ret, zscore = (amount - mean(amount))/ sd(amount), symbol), keyby = date
    ][, .(abnr_lead_ret = shift(abnr_ret, n = 1L, type = "lead"), zscore, symbol), keyby = symbol
    ][, summary(lm(abnr_lead_ret ~ zscore))$r.squared]
# Out:
# [1] 0.0003313487

# %% [markdown]
# #### *60. 每个股票的收益率和300、500指数收益率可以回归出一个截距项和2个beta，这两个beta的分布如何？*

# %%
data[, .(stkcd_ret = close/pre_close - 1, ind_w300_ret = sum((close/pre_close - 1) * index_w300), ind_w500_ret = sum((close/pre_close - 1) * index_w500), symbol), keyby = date
    ][, .(coef_beta = coef(lm(stkcd_ret ~ ind_w300_ret + ind_w500_ret))[-1], tag = c("ind_w300_ret", "ind_w500_ret")), keyby = symbol
    ][!is.na(coef_beta), .(sample_mean = mean(coef_beta), sample_sd = sd(coef_beta)), keyby = tag]
# Out:
#   tag          sample_mean sample_sd
# 1 ind_w300_ret -0.1583057  0.9317869
# 2 ind_w500_ret  1.1264276  0.8311509

# %% [markdown]
# #### *61. 每天开盘后到最高价涨幅最大的100只股票同样也是全天(昨收到今收)涨幅最大的100只股票的比例是多少?*

# %%
data[, .(high_open = high/open - 1, clo_pre = close/pre_close - 1), by = .(symbol, date)
    ][order(date, -high_open), .(ho_symbol = list(symbol[1:100])), keyby = date
    ][data[, .(high_open = high/open - 1, clo_pre = close/pre_close - 1), by = .(symbol, date)    
        ][order(date, -clo_pre), .(cp_symbol = list(symbol[1:100])), keyby = date], on = .(date)
    ][, {
        l <- list()
        for (i in 1:.N) {
            l[[i]] <- list(intec = intersect(cp_symbol[[i]], ho_symbol[[i]]))
        }
        rbindlist(l)
    }, keyby = date
    ][, .(ratio = .N/100), keyby = date]
# Out:
#     date     ratio
# 1   20120104 0.52
# 2   20120105 0.52
# 3   20120106 0.61
# 4   20120109 0.70
# 5   20120110 0.59
# 6   20120111 0.55
# 7   20120112 0.51
# 8   20120113 0.63
# 9   20120116 0.46
# 10  20120117 0.32
# 11  20120118 0.36
# 12  20120119 0.61
# 13  20120120 0.65
# 14  20120130 0.64
# 15  20120131 0.60
# 16  20120201 0.63
# 17  20120202 0.73
# 18  20120203 0.70
# 19  20120206 0.58
# 20  20120207 0.65
# 21  20120208 0.73
# 22  20120209 0.58
# 23  20120210 0.64
# 24  20120213 0.66
# 25  20120214 0.57
# 26  20120215 0.63
# 27  20120216 0.69
# 28  20120217 0.61
# 29  20120220 0.63
# 30  20120221 0.73
# ... ...      ...
# 88  20120518 0.58
# 89  20120521 0.65
# 90  20120522 0.67
# 91  20120523 0.68
# 92  20120524 0.72
# 93  20120525 0.67
# 94  20120528 0.80
# 95  20120529 0.65
# 96  20120530 0.67
# 97  20120531 0.70
# 98  20120601 0.66
# 99  20120604 0.59
# 100 20120605 0.61
# 101 20120606 0.72
# 102 20120607 0.63
# 103 20120608 0.67
# 104 20120611 0.78
# 105 20120612 0.64
# 106 20120613 0.77
# 107 20120614 0.71
# 108 20120615 0.63
# 109 20120618 0.64
# 110 20120619 0.65
# 111 20120620 0.73
# 112 20120621 0.65
# 113 20120625 0.68
# 114 20120626 0.67
# 115 20120627 0.64
# 116 20120628 0.58
# 117 20120629 0.68

# %% [markdown]
# #### *62. 每天计算最近三天每天对市场的超额收益率都排进当天前100的股票有哪些?*

# %%
data[, .(stkcd_ret = close/pre_close - 1, weight = capt/sum(capt), symbol), keyby = date
    ][, .(mkt_ret = sum(weight*stkcd_ret), stkcd_ret, symbol), keyby = date
    ][, .(alpha = coef(lm(stkcd_ret ~ mkt_ret))[1], beta = coef(lm(stkcd_ret ~ mkt_ret))[2], mkt_ret, stkcd_ret, symbol, date)
    ][, .(abnr_ret = stkcd_ret - alpha - beta * mkt_ret), keyby = .(date, symbol)
    ][order(date, -abnr_ret), .(symbol = list(symbol[1:100])), keyby = date
    ][, {
        l <- list()
        for (t in 4:.N) {
            l[[t]] <- list(symbol = Reduce(intersect, list(symbol[[t]], symbol[[t-1]], symbol[[t-2]])), date = date[[t]])
        }
        rbindlist(l)
    }]
# Out:
# Warning message in rbindlist(l):
# "Column 1 ['symbol'] of item 4 is length 0. This (and 10 others like it) has been filled with NA (NULL for list columns) to make each item uniform."
#     symbol    date
# 1   NA        20120109
# 2   000791.SZ 20120110
# 3   002118.SZ 20120111
# 4   600971.SH 20120111
# 5   000791.SZ 20120111
# 6   000552.SZ 20120111
# 7   600792.SH 20120111
# 8   600740.SH 20120111
# 9   000034.SZ 20120111
# 10  000835.SZ 20120111
# 11  600696.SH 20120111
# 12  600629.SH 20120111
# 13  000034.SZ 20120112
# 14  000552.SZ 20120112
# 15  002118.SZ 20120112
# 16  000791.SZ 20120112
# 17  600131.SH 20120112
# 18  600792.SH 20120112
# 19  000552.SZ 20120113
# 20  600515.SH 20120113
# 21  000856.SZ 20120113
# 22  000603.SZ 20120113
# 23  600448.SH 20120113
# 24  600515.SH 20120116
# 25  000603.SZ 20120116
# 26  NA        20120117
# 27  600568.SH 20120118
# 28  002428.SZ 20120119
# 29  002149.SZ 20120119
# 30  600549.SH 20120119
# ... ...       ...
# 305 000669.SZ 20120618
# 306 002349.SZ 20120619
# 307 300181.SZ 20120619
# 308 000056.SZ 20120619
# 309 002114.SZ 20120619
# 310 000669.SZ 20120619
# 311 000669.SZ 20120620
# 312 300252.SZ 20120620
# 313 002180.SZ 20120621
# 314 300205.SZ 20120621
# 315 300328.SZ 20120621
# 316 002684.SZ 20120625
# 317 300250.SZ 20120625
# 318 002180.SZ 20120625
# 319 002684.SZ 20120626
# 320 600613.SH 20120627
# 321 300319.SZ 20120627
# 322 002596.SZ 20120627
# 323 300084.SZ 20120627
# 324 002320.SZ 20120627
# 325 002586.SZ 20120627
# 326 600679.SH 20120627
# 327 000971.SZ 20120627
# 328 600896.SH 20120627
# 329 002596.SZ 20120628
# 330 300084.SZ 20120628
# 331 600687.SH 20120629
# 332 600702.SH 20120629
# 333 002653.SZ 20120629
# 334 300191.SZ 20120629

# %% [markdown]
# #### *63. 每天计算最近三天每天对行业的超额收益率都排进当天行业前30%的股票有哪些?*

# %%
data[, .(stkcd_ret = close/pre_close - 1, symbol, weight = capt/sum(capt)), keyby = .(industry,date)
    ][, .(ind_ret = sum(weight*stkcd_ret), stkcd_ret, symbol), keyby = .(industry, date)
    ][, .(alpha = coef(lm(stkcd_ret ~ ind_ret))[1], beta = coef(lm(stkcd_ret ~ ind_ret))[2], ind_ret, stkcd_ret, symbol, date), keyby = .(industry)
    ][, .(abnr_ret = stkcd_ret - alpha - beta * ind_ret), keyby = .(date, symbol)
    ][order(date, -abnr_ret) & abnr_ret > quantile(abnr_ret, 0.7), .(symbol = list(symbol)), keyby = date
    ][, {
        l <- list()
        for (t in 4:.N) {
            l[[t]] <- list(symbol = Reduce(intersect, list(symbol[[t]], symbol[[t-1]], symbol[[t-2]])), date = date[[t]])
        }
        rbindlist(l)
    }]
# Out:
#      symbol    date
# 1    000039.SZ 20120109
# 2    000045.SZ 20120109
# 3    000411.SZ 20120109
# 4    000422.SZ 20120109
# 5    000518.SZ 20120109
# 6    000528.SZ 20120109
# 7    000607.SZ 20120109
# 8    000623.SZ 20120109
# 9    000666.SZ 20120109
# 10   000707.SZ 20120109
# 11   000735.SZ 20120109
# 12   000982.SZ 20120109
# 13   002022.SZ 20120109
# 14   002056.SZ 20120109
# 15   002083.SZ 20120109
# 16   002136.SZ 20120109
# 17   002141.SZ 20120109
# 18   002155.SZ 20120109
# 19   002164.SZ 20120109
# 20   002200.SZ 20120109
# 21   002280.SZ 20120109
# 22   002379.SZ 20120109
# 23   002404.SZ 20120109
# 24   002480.SZ 20120109
# 25   002627.SZ 20120109
# 26   002628.SZ 20120109
# 27   300002.SZ 20120109
# 28   300149.SZ 20120109
# 29   300209.SZ 20120109
# 30   300245.SZ 20120109
# ...  ...       ...
# 7772 300282.SZ 20120629
# 7773 300285.SZ 20120629
# 7774 300290.SZ 20120629
# 7775 300293.SZ 20120629
# 7776 300294.SZ 20120629
# 7777 300296.SZ 20120629
# 7778 300322.SZ 20120629
# 7779 600051.SH 20120629
# 7780 600072.SH 20120629
# 7781 600073.SH 20120629
# 7782 600082.SH 20120629
# 7783 600085.SH 20120629
# 7784 600097.SH 20120629
# 7785 600199.SH 20120629
# 7786 600260.SH 20120629
# 7787 600285.SH 20120629
# 7788 600290.SH 20120629
# 7789 600478.SH 20120629
# 7790 600498.SH 20120629
# 7791 600543.SH 20120629
# 7792 600559.SH 20120629
# 7793 600663.SH 20120629
# 7794 600687.SH 20120629
# 7795 600702.SH 20120629
# 7796 600873.SH 20120629
# 7797 600981.SH 20120629
# 7798 601231.SH 20120629
# 7799 601633.SH 20120629
# 7800 601886.SH 20120629
# 7801 601928.SH 20120629
